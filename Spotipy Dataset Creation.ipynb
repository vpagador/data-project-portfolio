# %%
import pandas as pd
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# ## Authentication

# %%
spotify_client_info = pd.read_csv('Spotify_auth_cred_flow.csv', header=None)
client_id = spotify_client_info.iloc[0,0]
client_secret = spotify_client_info.iloc[1,0]
redirect_uri = spotify_client_info.iloc[2,0]

# %%
scope = 'user-library-read'

auth_manager = SpotifyOAuth(client_id, client_secret, redirect_uri, scope=scope)

# %%
# Opens browser to login
auth_manager.get_auth_response()
# Out:
# 'AQA-BrZ8bU5A70rFT6oW1Ur3oo1eWcC-OGSzSrl5H844cIxxwCceLP85b-UancVUv0o49XpsaxzmgPyjGhSdof49vhH_qo8j7AEfyGzDsh6hSqQTN8GLh7wDF0VwWVIruuC022CQQ43YJZucpJ_19flAR0ivHdzwNI_x8qEzg4no62P-baG4CV0rI-U'

# %% [markdown]
# ## Get Playlist Songs

# %%
# Function to retrieve song data from Spotify API
sp = spotipy.Spotify(auth_manager= auth_manager)

# %%
# Retrieves Songs from 3 Playlists:
# Faves Skillet+ (Rock, Metal)
# Faves Vint Vibes (Disco, Funk, Rock Pop, Old Ballads)
# Faves Chilled Soul (RnB, Soul, Slow pop)
playlist_ids = ['https://open.spotify.com/playlist/1fe3iAJDParVnIt1t7C8xw?si=74244980c18d4bfc',
                'https://open.spotify.com/playlist/1A80GmIeSnZo29E0OBokMK?si=7dd80542d03a45ac',
               'https://open.spotify.com/playlist/5aOKSZJxYaCg81yZDiZcqV?si=be4363b21f1c4496']

# %%
# Make list of compiled song names
compiled_songs = []
for playlist in playlist_ids:
    song = sp.playlist(playlist)['tracks']['items']
    for i in range(100):
        compiled_songs.append(song[i]['track']['name'])
print(compiled_songs)
# Out:
# ['Feel Invincible', 'Save Me', 'Dominion', 'Hail to the King', 'One Step Closer', 'Open Wounds', 'Respect', 'Vapor', 'Since U Been Gone', 'Energy', 'Agree to Disagree', 'Alien Youth', 'Jesus Freak - Remastered 2013', 'Good Man', 'Hero', 'Breathe Into Me', 'Surviving The Game', 'Afterlife', 'Rise Above It', 'Lightning In The Sky', 'White Horse', 'Locked in a Cage', 'Scars', 'Take It Out On Me', 'Carry On', 'Standing in the Storm', 'Rise Up', 'Gunslinger', 'Collide', 'Comatose', 'Sick of It', 'Whispers in the Dark', 'Better Than Drugs', 'The Last Night', 'Victorious', 'Forsaken', 'Legendary', 'My Obsession', 'Cycle Down', 'Back to Life', 'Savior', 'The Resistance', 'I Want to Live', 'Under My Skin', 'Awake and Alive', 'Never Going Back', 'Circus for a Psycho', "Rippin' Me Off", 'Rebirthing', 'Rise', 'Not Gonna Die', 'Terrify the Dark', 'Stronger', 'Anchor', 'My Arms', 'Kill Me, Heal Me', 'Fingernails', 'A Little More', 'Falling Inside the Black', 'Those Nights', 'Dead Man Walking', 'What I Believe', 'Sometimes', 'Believe', 'Never Surrender', 'This Is the Kingdom', 'Forgiven', 'Sick and Empty', "You Ain't Ready", 'Back from the Dead', 'Out of Hell', 'Reach', 'Welcome to the Family', 'Unholy Confessions', 'Shepherd of Fire', 'Almost Easy', 'Nightmare', 'Barriers', 'The Bottom', 'You and Not Me', 'Bow Down', 'DOA', 'Low', 'Hurricane', 'Every Time You Leave', 'Stuck In Your Head', 'Lifelines', 'Come And Get It', 'RISE', 'Pull The Plug', 'Already Dead', 'Never Give Up', 'Get Me Out', "Wouldn't You Rather", 'I Will Not Bow', 'Metalingus', 'I Hate Everything About You', 'Breath', 'Drunk', 'Crooked Soul', 'Africa', 'Plastic Love', 'More Than a Feeling', "Reelin' In The Years", 'Forget Me Nots', 'I Wanna Be Your Lover', 'Lovely Day', 'The Way You Make Me Feel - 2012 Remaster', 'Never Too Much', 'Touch Me', "Don't Stop Believin'", 'Wonderwall - Remastered', 'Rock With You - Single Version', 'I Wish', 'Come and Get Your Love - Single Version', 'Johnny B. Goode', 'Got to Be Real - Single Version', "Let's Groove", 'Peace of Mind', 'Never Gonna Give You Up', 'Kiss', "U Can't Touch This", 'September', 'Good Times', 'The Best - Edit', 'Everybody Wants To Rule The World', 'Night Fever - From "Saturday Night Fever" Soundtrack', "Don't Stop - 2004 Remaster", "Don't Stop 'Til You Get Enough - Single Version", 'Escape (The Pina Colada Song)', 'Kid Charlemagne', 'Go Your Own Way - 2004 Remaster', 'Champagne Supernova', 'Your Love', 'All Right Now', 'Head Over Heels - Dave Bascombe 7" N.Mix', "Let's Dance - 1999 Remaster", 'You Spin Me Round (Like a Record)', 'Take on Me', "Let's Go Crazy", 'Enjoy the Silence', "Free Fallin'", 'Take It Easy - 2013 Remaster', 'Hotel California - 2013 Remaster', 'Message In A Bottle', 'Every Little Thing She Does Is Magic', 'Carry on Wayward Son', "Summer Of '69", 'Born to Run', 'Walk This Way', 'Hold the Line', 'Any Way You Want It', 'Come Together - Remastered 2009', 'Day Tripper - Remastered 2015', 'Back In The U.S.S.R. - 2018 Mix', 'Layla - Live At Hammersmith Odeon', 'Road Games (Jack Bruce) - Remastered', 'We Will Rock You - Remastered 2011', "I Was Made For Lovin' You", "Ain't Nobody", 'Do I Do', 'P.Y.T. (Pretty Young Thing)', "Workin' Day and Night", 'Billie Jean', 'Smooth Criminal - 2012 Remaster', 'Beat It', 'Le Freak', 'Blame It on the Boogie', 'I Want You Back', '1999 - Edit', 'Boogie Wonderland', 'Stomp! - Single Version', 'Stayin\' Alive - From "Saturday Night Fever" Soundtrack', 'We Are Family', 'Sir Duke', 'Superstition - Single Version', "That's the Way (I Like It)", 'Brick House', "Baba O'Riley", 'My Generation - Stereo Version', 'Who Are You', 'Fast Car', 'After the Love Has Gone', 'After The Storm', 'Tears in Heaven - Acoustic; Live at MTV Unplugged, Bray Film Studios, Windsor, England, UK, 1/16/1992; 2013 Remaster', 'Wonderful Tonight', 'Just Take My Heart - 2010 Remastered Version', 'Purple Rain', 'I Don\'t Want to Miss a Thing - From "Armageddon" Soundtrack', 'Wild World - 2009 Remastered Version' ...

# %%
# total song names retrieved
print(len(compiled_songs))
# Out:
# 300

# %%
# Check first 100 songs
print(compiled_songs[0:100])
# Out:
# ['Feel Invincible', 'Save Me', 'Dominion', 'Hail to the King', 'One Step Closer', 'Open Wounds', 'Respect', 'Vapor', 'Since U Been Gone', 'Energy', 'Agree to Disagree', 'Alien Youth', 'Jesus Freak - Remastered 2013', 'Good Man', 'Hero', 'Breathe Into Me', 'Surviving The Game', 'Afterlife', 'Rise Above It', 'Lightning In The Sky', 'White Horse', 'Locked in a Cage', 'Scars', 'Take It Out On Me', 'Carry On', 'Standing in the Storm', 'Rise Up', 'Gunslinger', 'Collide', 'Comatose', 'Sick of It', 'Whispers in the Dark', 'Better Than Drugs', 'The Last Night', 'Victorious', 'Forsaken', 'Legendary', 'My Obsession', 'Cycle Down', 'Back to Life', 'Savior', 'The Resistance', 'I Want to Live', 'Under My Skin', 'Awake and Alive', 'Never Going Back', 'Circus for a Psycho', "Rippin' Me Off", 'Rebirthing', 'Rise', 'Not Gonna Die', 'Terrify the Dark', 'Stronger', 'Anchor', 'My Arms', 'Kill Me, Heal Me', 'Fingernails', 'A Little More', 'Falling Inside the Black', 'Those Nights', 'Dead Man Walking', 'What I Believe', 'Sometimes', 'Believe', 'Never Surrender', 'This Is the Kingdom', 'Forgiven', 'Sick and Empty', "You Ain't Ready", 'Back from the Dead', 'Out of Hell', 'Reach', 'Welcome to the Family', 'Unholy Confessions', 'Shepherd of Fire', 'Almost Easy', 'Nightmare', 'Barriers', 'The Bottom', 'You and Not Me', 'Bow Down', 'DOA', 'Low', 'Hurricane', 'Every Time You Leave', 'Stuck In Your Head', 'Lifelines', 'Come And Get It', 'RISE', 'Pull The Plug', 'Already Dead', 'Never Give Up', 'Get Me Out', "Wouldn't You Rather", 'I Will Not Bow', 'Metalingus', 'I Hate Everything About You', 'Breath', 'Drunk', 'Crooked Soul']

# %%
def get_song_features():
    song_names = []
    song_artists = []
    song_features = []
    
    for playlist in playlist_ids:
        song = sp.playlist(playlist)
        for i in range(100):
            song_name = song['tracks']['items'][i]['track']['name']
            song_artist = song['tracks']['items'][i]['track']['album']['artists'][0]['name']
            features = sp.audio_features(song['tracks']['items'][i]['track']['id'])[0]
            song_names.append(song_name)
            song_artists.append(song_artist)
            song_features.append(features)

    return song_names, song_artists, song_features

# %%
get_song_features()
# Out:
# (['Feel Invincible',
#   'Save Me',
#   'Dominion',
#   'Hail to the King',
#   'One Step Closer',
#   'Open Wounds',
#   'Respect',
#   'Vapor',
#   'Since U Been Gone',
#   'Energy',
#   'Agree to Disagree',
#   'Alien Youth',
#   'Jesus Freak - Remastered 2013',
#   'Good Man',
#   'Hero',
#   'Breathe Into Me',
#   'Surviving The Game',
#   'Afterlife',
#   'Rise Above It',
#   'Lightning In The Sky',
#   'White Horse',
#   'Locked in a Cage',
#   'Scars',
#   'Take It Out On Me',
#   'Carry On',
#   'Standing in the Storm',
#   'Rise Up',
#   'Gunslinger',
#   'Collide',
#   'Comatose',
#   'Sick of It',
#   'Whispers in the Dark',
#   'Better Than Drugs',
#   'The Last Night',
#   'Victorious',
#   'Forsaken',
#   'Legendary',
#   'My Obsession',
#   'Cycle Down',
#   'Back to Life',
#   'Savior',
#   'The Resistance',
#   'I Want to Live',
#   'Under My Skin',
#   'Awake and Alive',
#   'Never Going Back',
#   'Circus for a Psycho',
#   "Rippin' Me Off",
#   'Rebirthing',
#   'Rise',
#   'Not Gonna Die',
#   'Terrify the Dark',
#   'Stronger',
#   'Anchor',
#   'My Arms',
#   'Kill Me, Heal Me',
#   'Fingernails',
#   'A Little More',
#   'Falling Inside the Black',
#   'Those Nights',
#   'Dead Man Walking',
#   'What I Believe',
#   'Sometimes',
#   'Believe',
#   'Never Surrender',
#   'This Is the Kingdom',
#   'Forgiven',
#   'Sick and Empty',
#   "You Ain't Ready",
#   'Back from the Dead',
#   'Out of Hell',
#   'Reach',
#   'Welcome to the Family',
#   'Unholy Confessions',
#   'Shepherd of Fire',
#   'Almost Easy',
#   'Nightmare',
#   'Barriers',
#   'The Bottom',
#   'You and Not Me',
#   'Bow Down',
#   'DOA',
#   'Low',
#   'Hurricane',
#   'Every Time You Leave',
#   'Stuck In Your Head',
#   'Lifelines',
#   'Come And Get It',
#   'RISE',
#   'Pull The Plug',
#   'Already Dead',
#   'Never Give Up',
#   'Get Me Out',
#   "Wouldn't You Rather",
#   'I Will Not Bow',
#   'Metalingus',
#   'I Hate Everything About You',
#   'Breath',
#   'Drunk',
#   'Crooked Soul',
#   'Africa',
#   'Plastic Love',
#   'More Than a Feeling',
#   "Reelin' In The Years",
#   'Forget Me Nots',
#   'I Wanna Be Your Lover',
#   'Lovely Day',
#   'The Way You Make Me Feel - 2012 Remaster',
#   'Never Too Much',
#   'Touch Me',
#   "Don't Stop Believin'",
#   'Wonderwall - Remastered',
#   'Rock With You - Single Version',
#   'I Wish',
#   'Come and Get Your Love - Single Version',
#   'Johnny B. Goode',
#   'Got to Be Real - Single Version',
#   "Let's Groove",
#   'Peace of Mind',
#   'Never Gonna Give You Up',
#   'Kiss',
#   "U Can't Touch This",
#   'September',
#   'Good Times',
#   'The Best - Edit',
#   'Everybody Wants To Rule The World',
#   'Night Fever - From "Saturday Night Fever" Soundtrack',
#   "Don't Stop - 2004 Remaster",
#   "Don't Stop 'Til You Get Enough - Single Version",
#   'Escape (The Pina Colada Song)',
#   'Kid Charlemagne',
#   'Go Your Own Way - 2004 Remaster',
#   'Champagne Supernova',
#   'Your Love',
#   'All Right Now',
#   'Head Over Heels - Dave Bascombe 7" N.Mix',
#   "Let's Dance - 1999 Remaster",
#   'You Spin Me Round (Like a Record)',
#   'Take on Me',
#   "Let's Go Crazy",
#   'Enjoy the Silence',
#   "Free Fallin'",
#   'Take It Easy - 2013 Remaster',
#   'Hotel California - 2013 Remaster',
#   'Message In A Bottle',
#   'Every Little Thing She Does Is Magic',
#   'Carry on Wayward Son',
#   "Summer Of '69",
#   'Born to Run',
#   'Walk This Way',
#   'Hold the Line',
#   'Any Way You Want It',
#   'Come Together - Remastered 2009',
#   'Day Tripper - Remastered 2015',
#   'Back In The U.S.S.R. - 2018 Mix',
#   'Layla - Live At Hammersmith Odeon',
#   'Road Games (Jack Bruce) - Remastered',
#   'We Will Rock You - Remastered 2011',
#   "I Was Made For Lovin' You",
#   "Ain't Nobody",
#   'Do I Do',
#   'P.Y.T. (Pretty Young Thing)',
#   "Workin' Day and Night",
#   'Billie Jean',
#   'Smooth Criminal - 2012 Remaster',
#   'Beat It',
#   'Le Freak',
#   'Blame It on the Boogie',
#   'I Want You Back',
#   '1999 - Edit',
#   'Boogie Wonderland',
#   'Stomp! - Single Version',
#   'Stayin\' Alive - From "Saturday Night Fever" Soundtrack',
#   'We Are Family',
#   'Sir Duke',
#   'Superstition - Single Version',
#   "That's the Way (I Like It)",
#   'Brick House',
#   "Baba O'Riley",
#   'My Generation - Stereo Version',
#   'Who Are You',
#   'Fast Car',
#   'After the Love Has Gone',
#   'After The Storm',
#   'Tears in Heaven - Acoustic; Live at MTV Unplugged, Bray Film Studios, Windsor, England, UK, 1/16/1992; 2013 Remaster',
#   'Wonderful Tonight',
#   'Just Take My Heart - 2010 Remastered Version',
#   'Purple Rain',
#   'I Don\'t Want to Miss a Thing - From "Armageddon" Soundtrack',
#   'Wild World - 2009 Remastered Version',
#   'To Be With You - 2010 Remastered Version',
#   'Amanda',
#   'Nothing Compares 2 U',
#   'Heart of Gold - 2009 Remaster',
#   'Blackbird - Remastered 2009',
#   'Here Comes The Sun - Remastered 2009',
#   'Something - Remastered 2009',
#   'Oh! Darling - 2019 Mix',
#   'While My Guitar Gently Weeps - 2018 Mix',
#   'Penny Lane - Remastered',
#   'The Most Beautiful Thing',
#   'Face To Face',
#   'Would You Believe',
#   'some people',
#   'Better',
#   'Easily',
#   'Nothing',
#   'Sure Thing',
#   'Written In The Stars',
#   'Slow Down',
#   'Focus',
#   'Every Kind Of Way',
#   'Best Part (feat. Daniel Caesar)',
#   "Not Thinkin' Bout You",
#   'Hard Place',
#   'U',
#   'Avenue',
#   'Gone Away',
#   'Lights On',
#   'As I Am',
#   'Get You (feat. Kali Uchis)',
#   'Slumber',
#   'Home',
#   'Like Someone In Love',
#   'Old Soul',
#   "Wouldn't Mean A Thing",
#   'You Give Me Something - Live At The Hospital Club',
#   '26',
#   'Say',
#   'Saturday Sun',
#   'On Your Way Home',
#   'Call If You Need Me',
#   'Easy',
#   'Hold Back The River',
#   'Scars',
#   'Too Late For Lullabies',
#   'justified',
#   'Those Sweet Words',
#   'Let It Go',
#   'Georgia',
#   'Better Together',
#   'Weak',
#   'Stickwitu',
#   'Alaska',
#   'Call It What You Want',
#   "Can't Help Falling in Love",
#   'Drive',
#   'Easy',
#   'The Only Exception',
#   'Stay',
#   'Need The Sun To Break',
#   "If I Ain't Got You",
#   'Dear No One',
#   'Paper Hearts',
#   'Tell Me Where It Hurts',
#   'The Closer I Get to You',
#   'Say You Love Me',
#   'Tango',
#   'The Weekend',
#   'SUPERPOSITION',
#   'loyal',
#   'take care',
#   'more',
#   'Light On',
#   'colour (amen)',
#   'The Wrong Ones',
#   "Ain't Nobody (Loves Me Better) - Acoustic",
#   'Waterfalls',
#   'lowkey',
#   'Tadhana',
#   'Turn It Well',
#   'Parks',
#   'Night Drops',
#   'Kulang',
#   'Guiding Light',
#   'It Takes Two',
#   '12:45 - Stripped',
#   'Cherry Wine',
#   'How Deep Is Your Love',
#   'Take A Bow',
#   'Sunny Days, Summer Nights',
#   'SEATTLE',
#   'Through the Night',
#   'Dear Name',
#   'Flower Way (Prod. By ZICO)',
#   'If I Ain’t Got You - James Bay Spotify Session 2015 "Alicia Keys Cover"',
#   'Slow Dancing in a Burning Room',
#   'Edge of Desire',
#   'Gravity',
#   "Shouldn't Matter but It Does",
#   'Why You No Love Me',
#   'In Repair',
#   'The Heart of Life',
#   'Love on the Weekend',
#   'Moving On and Getting Over',
#   'Rosie',
#   'Transcend - feat. Armi',
#   "You're On My Mind",
#   'golden thing',
#   'Tonight'],
#  ['Skillet',
#   'Skillet',
#   'Skillet',
#   'Avenged Sevenfold',
#   'Linkin Park',
#   'Skillet',
#   'Devour the Day',
#   'Skillet',
#   'A Day To Remember',
#   'Skillet',
#   'Sleeping With Sirens',
#   'Skillet',
#   'DC Talk',
#   'Devour the Day',
#   'Skillet',
#   'Red',
#   'Skillet',
#   'Avenged Sevenfold',
#   'I Prevail',
#   'Devour the Day',
#   'Skillet',
#   'Skillet',
#   'I Prevail',
#   'Thousand Foot Krutch',
#   'Avenged Sevenfold',
#   'Skillet',
#   'Skillet',
#   'Avenged Sevenfold',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'LEDGER',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Skillet',
#   'Avenged Sevenfold',
#   'Avenged Sevenfold',
#   'Avenged Sevenfold',
#   'Avenged Sevenfold',
#   'Avenged Sevenfold',
#   'BURSTERS',
#   'Devour the Day',
#   'Devour the Day',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'I Prevail',
#   'Stealing Eden',
#   'No Resolve',
#   'Alter Bridge',
#   'Breaking Benjamin',
#   'Alter Bridge',
#   'Three Days Grace',
#   'Breaking Benjamin',
#   'Dayseeker',
#   'Dayseeker',
#   'TOTO',
#   'Mariya Takeuchi',
#   'Boston',
#   'Steely Dan',
#   'Patrice Rushen',
#   'Prince',
#   'Bill Withers',
#   'Michael Jackson',
#   'Luther Vandross',
#   'The Doors',
#   'Journey',
#   'Oasis',
#   'Michael Jackson',
#   'Stevie Wonder',
#   'Redbone',
#   'Chuck Berry',
#   'Cheryl Lynn',
#   'Earth, Wind & Fire',
#   'Boston',
#   'Rick Astley',
#   'Prince',
#   'MC Hammer',
#   'Earth, Wind & Fire',
#   'CHIC',
#   'Tina Turner',
#   'Tears For Fears',
#   'Bee Gees',
#   'Fleetwood Mac',
#   'Michael Jackson',
#   'Rupert Holmes',
#   'Steely Dan',
#   'Fleetwood Mac',
#   'Oasis',
#   'The Outfield',
#   'Free',
#   'Tears For Fears',
#   'David Bowie',
#   'Dead Or Alive',
#   'a-ha',
#   'Prince',
#   'Depeche Mode',
#   'Tom Petty',
#   'Eagles',
#   'Eagles',
#   'The Police',
#   'The Police',
#   'Kansas',
#   'Bryan Adams',
#   'Bruce Springsteen',
#   'Aerosmith',
#   'TOTO',
#   'Journey',
#   'The Beatles',
#   'The Beatles',
#   'The Beatles',
#   'Eric Clapton',
#   'Allan Holdsworth',
#   'Queen',
#   'KISS',
#   'Chaka Khan',
#   'Stevie Wonder',
#   'Michael Jackson',
#   'Michael Jackson',
#   'Michael Jackson',
#   'Michael Jackson',
#   'Michael Jackson',
#   'CHIC',
#   'The Jacksons',
#   'The Jackson 5',
#   'Prince',
#   'Earth, Wind & Fire',
#   'The Brothers Johnson',
#   'Bee Gees',
#   'Sister Sledge',
#   'Stevie Wonder',
#   'Stevie Wonder',
#   'KC & The Sunshine Band',
#   'Commodores',
#   'The Who',
#   'The Who',
#   'The Who',
#   'Tracy Chapman',
#   'Earth, Wind & Fire',
#   'Norman Brown',
#   'Eric Clapton',
#   'Eric Clapton',
#   'Mr. Big',
#   'Prince',
#   'Various Artists',
#   'Mr. Big',
#   'Mr. Big',
#   'Boston',
#   'Prince',
#   'Neil Young',
#   'The Beatles',
#   'The Beatles',
#   'The Beatles',
#   'The Beatles',
#   'The Beatles',
#   'The Beatles',
#   'Bruno Major',
#   'Ruel',
#   'Sam Kim',
#   'Jasmine Thompson',
#   'Khalid',
#   'Bruno Major',
#   'Bruno Major',
#   'Miguel',
#   'WENDY',
#   'Mac Ayres',
#   'H.E.R.',
#   'H.E.R.',
#   'H.E.R.',
#   'Ruel',
#   'H.E.R.',
#   'H.E.R.',
#   'H.E.R.',
#   'H.E.R.',
#   'H.E.R.',
#   'H.E.R.',
#   'Daniel Caesar',
#   'Lewis Watson',
#   'Bruno Major',
#   'Bruno Major',
#   'Bruno Major',
#   'Bruno Major',
#   'James Morrison',
#   'Paramore',
#   'Various Artists',
#   'Vance Joy',
#   'Patrick Droney',
#   'Vance Joy',
#   'Mac Ayres',
#   'James Bay',
#   'James Bay',
#   'James Morrison',
#   'Kacey Musgraves',
#   'Norah Jones',
#   'James Bay',
#   'Vance Joy',
#   'Jack Johnson',
#   'SWV',
#   'The Pussycat Dolls',
#   'Maggie Rogers',
#   'Taylor Swift',
#   'Haley Reinhart',
#   'Incubus',
#   'Commodores',
#   'Paramore',
#   'Mac Ayres',
#   'James Bay',
#   'Alicia Keys',
#   'Tori Kelly',
#   'Tori Kelly',
#   'MYMP',
#   'MYMP',
#   'MYMP',
#   'ABIR',
#   'SZA',
#   'Daniel Caesar',
#   'Jasmine Thompson',
#   'Jasmine Thompson',
#   'Jasmine Thompson',
#   'Maggie Rogers',
#   'Jasmine Thompson',
#   'JC Stewart',
#   'Jasmine Thompson',
#   'TLC',
#   'NIKI',
#   'Up Dharma Down',
#   'Up Dharma Down',
#   'Up Dharma Down',
#   'Up Dharma Down',
#   'Up Dharma Down',
#   'Foy Vance',
#   'Fiji Blue',
#   'Etham',
#   'grentperez',
#   'PJ Morton',
#   'Rihanna',
#   'Sam Kim',
#   'Sam Kim',
#   'IU',
#   'IU',
#   'KIMSEJEONG',
#   'James Bay',
#   'John Mayer',
#   'John Mayer',
#   'John Mayer',
#   'John Mayer',
#   'John Mayer',
#   'John Mayer',
#   'John Mayer',
#   'John Mayer',
#   'John Mayer',
#   'John Mayer',
#   'Ovall',
#   'Tom Misch',
#   'Cody Simpson',
#   'Stephen Day'],
#  [{'danceability': 0.603,
#    'energy': 0.886,
#    'key': 5,
#    'loudness': -3.777,
#    'mode': 0,
#    'speechiness': 0.0837,
#    'acousticness': 0.00045,
#    'instrumentalness': 0,
#    'liveness': 0.26,
#    'valence': 0.395,
#    'tempo': 126.025,
#    'type': 'audio_features',
#    'id': '0i8JFpqe9cKwnrcvoNgl1L',
#    'uri': 'spotify:track:0i8JFpqe9cKwnrcvoNgl1L',
#    'track_href': 'https://api.spotify.com/v1/tracks/0i8JFpqe9cKwnrcvoNgl1L',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0i8JFpqe9cKwnrcvoNgl1L',
#    'duration_ms': 229933,
#    'time_signature': 4},
#   {'danceability': 0.556,
#    'energy': 0.888,
#    'key': 1,
#    'loudness': -3.985,
#    'mode': 0,
#    'speechiness': 0.0377,
#    'acousticness': 0.000377,
#    'instrumentalness': 0,
#    'liveness': 0.214,
#    'valence': 0.446,
#    'tempo': 96.033,
#    'type': 'audio_features',
#    'id': '4pJM8ZZ3YIO4xOeD5k8s5P',
#    'uri': 'spotify:track:4pJM8ZZ3YIO4xOeD5k8s5P',
#    'track_href': 'https://api.spotify.com/v1/tracks/4pJM8ZZ3YIO4xOeD5k8s5P',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4pJM8ZZ3YIO4xOeD5k8s5P',
#    'duration_ms': 223241,
#    'time_signature': 4},
#   {'danceability': 0.407,
#    'energy': 0.99,
#    'key': 11,
#    'loudness': -3.969,
#    'mode': 0,
#    'speechiness': 0.171,
#    'acousticness': 0.0306,
#    'instrumentalness': 0,
#    'liveness': 0.0708,
#    'valence': 0.186,
#    'tempo': 164.977,
#    'type': 'audio_features',
#    'id': '08y95NOBjAM41gJfSqTogE',
#    'uri': 'spotify:track:08y95NOBjAM41gJfSqTogE',
#    'track_href': 'https://api.spotify.com/v1/tracks/08y95NOBjAM41gJfSqTogE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/08y95NOBjAM41gJfSqTogE',
#    'duration_ms': 231492,
#    'time_signature': 4},
#   {'danceability': 0.58,
#    'energy': 0.916,
#    'key': 3,
#    'loudness': -4.358,
#    'mode': 0,
#    'speechiness': 0.0387,
#    'acousticness': 0.000297,
#    'instrumentalness': 0.0259,
#    'liveness': 0.126,
#    'valence': 0.683,
#    'tempo': 118.004,
#    'type': 'audio_features',
#    'id': '5anCkDvJ17aznvK5TED5uo',
#    'uri': 'spotify:track:5anCkDvJ17aznvK5TED5uo',
#    'track_href': 'https://api.spotify.com/v1/tracks/5anCkDvJ17aznvK5TED5uo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5anCkDvJ17aznvK5TED5uo',
#    'duration_ms': 305907,
#    'time_signature': 4},
#   {'danceability': 0.492,
#    'energy': 0.969,
#    'key': 9,
#    'loudness': -4.419,
#    'mode': 1,
#    'speechiness': 0.0491,
#    'acousticness': 0.0014,
#    'instrumentalness': 1.32e-06,
#    'liveness': 0.0787,
#    'valence': 0.538,
#    'tempo': 95.136,
#    'type': 'audio_features',
#    'id': '3K4HG9evC7dg3N0R9cYqk4',
#    'uri': 'spotify:track:3K4HG9evC7dg3N0R9cYqk4',
#    'track_href': 'https://api.spotify.com/v1/tracks/3K4HG9evC7dg3N0R9cYqk4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3K4HG9evC7dg3N0R9cYqk4',
#    'duration_ms': 157333,
#    'time_signature': 4},
#   {'danceability': 0.573,
#    'energy': 0.922,
#    'key': 0,
#    'loudness': -4.013,
#    'mode': 1,
#    'speechiness': 0.0695,
#    'acousticness': 0.0595,
#    'instrumentalness': 0,
#    'liveness': 0.414,
#    'valence': 0.503,
#    'tempo': 101.099,
#    'type': 'audio_features',
#    'id': '2UfKuGYONPAuopJtpGfZyA',
#    'uri': 'spotify:track:2UfKuGYONPAuopJtpGfZyA',
#    'track_href': 'https://api.spotify.com/v1/tracks/2UfKuGYONPAuopJtpGfZyA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2UfKuGYONPAuopJtpGfZyA',
#    'duration_ms': 194773,
#    'time_signature': 4},
#   {'danceability': 0.654,
#    'energy': 0.818,
#    'key': 8,
#    'loudness': -6.12,
#    'mode': 1,
#    'speechiness': 0.0434,
#    'acousticness': 0.00012,
#    'instrumentalness': 7.45e-05,
#    'liveness': 0.233,
#    'valence': 0.348,
#    'tempo': 118.045,
#    'type': 'audio_features',
#    'id': '56Q1OQHsZcCqYwLFAjDWWT',
#    'uri': 'spotify:track:56Q1OQHsZcCqYwLFAjDWWT',
#    'track_href': 'https://api.spotify.com/v1/tracks/56Q1OQHsZcCqYwLFAjDWWT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56Q1OQHsZcCqYwLFAjDWWT',
#    'duration_ms': 171262,
#    'time_signature': 4},
#   {'danceability': 0.394,
#    'energy': 0.982,
#    'key': 5,
#    'loudness': -3.94,
#    'mode': 1,
#    'speechiness': 0.0839,
#    'acousticness': 9.5e-05,
#    'instrumentalness': 3.44e-06,
#    'liveness': 0.0665,
#    'valence': 0.412,
#    'tempo': 188.29,
#    'type': 'audio_features',
#    'id': '2ehrjxv9XbxKekKwEQ1ZAl',
#    'uri': 'spotify:track:2ehrjxv9XbxKekKwEQ1ZAl',
#    'track_href': 'https://api.spotify.com/v1/tracks/2ehrjxv9XbxKekKwEQ1ZAl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2ehrjxv9XbxKekKwEQ1ZAl',
#    'duration_ms': 218707,
#    'time_signature': 4},
#   {'danceability': 0.625,
#    'energy': 0.951,
#    'key': 3,
#    'loudness': -5.209,
#    'mode': 1,
#    'speechiness': 0.0494,
#    'acousticness': 0.00497,
#    'instrumentalness': 0,
#    'liveness': 0.106,
#    'valence': 0.721,
#    'tempo': 128.01,
#    'type': 'audio_features',
#    'id': '1HykUKaVU0CEUvv1vLKkXj',
#    'uri': 'spotify:track:1HykUKaVU0CEUvv1vLKkXj',
#    'track_href': 'https://api.spotify.com/v1/tracks/1HykUKaVU0CEUvv1vLKkXj',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1HykUKaVU0CEUvv1vLKkXj',
#    'duration_ms': 198267,
#    'time_signature': 4},
#   {'danceability': 0.441,
#    'energy': 0.958,
#    'key': 7,
#    'loudness': -3.256,
#    'mode': 1,
#    'speechiness': 0.0757,
#    'acousticness': 0.000413,
#    'instrumentalness': 2.26e-05,
#    'liveness': 0.103,
#    'valence': 0.354,
#    'tempo': 92.974,
#    'type': 'audio_features',
#    'id': '1YJ6AWU6RPVuHfi0wwOEsC',
#    'uri': 'spotify:track:1YJ6AWU6RPVuHfi0wwOEsC',
#    'track_href': 'https://api.spotify.com/v1/tracks/1YJ6AWU6RPVuHfi0wwOEsC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1YJ6AWU6RPVuHfi0wwOEsC',
#    'duration_ms': 236693,
#    'time_signature': 4},
#   {'danceability': 0.561,
#    'energy': 0.935,
#    'key': 1,
#    'loudness': -3.807,
#    'mode': 1,
#    'speechiness': 0.0936,
#    'acousticness': 0.011,
#    'instrumentalness': 0,
#    'liveness': 0.26,
#    'valence': 0.625,
#    'tempo': 89.973,
#    'type': 'audio_features',
#    'id': '58Eyr2rZWIYM19qhpals74',
#    'uri': 'spotify:track:58Eyr2rZWIYM19qhpals74',
#    'track_href': 'https://api.spotify.com/v1/tracks/58Eyr2rZWIYM19qhpals74',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/58Eyr2rZWIYM19qhpals74',
#    'duration_ms': 182680,
#    'time_signature': 4},
#   {'danceability': 0.344,
#    'energy': 0.944,
#    'key': 0,
#    'loudness': -4.232,
#    'mode': 0,
#    'speechiness': 0.118,
#    'acousticness': 9.23e-05,
#    'instrumentalness': 1.04e-05,
#    'liveness': 0.324,
#    'valence': 0.38,
#    'tempo': 188.395,
#    'type': 'audio_features',
#    'id': '0KIkxS3hprDuiDIqMHTfG9',
#    'uri': 'spotify:track:0KIkxS3hprDuiDIqMHTfG9',
#    'track_href': 'https://api.spotify.com/v1/tracks/0KIkxS3hprDuiDIqMHTfG9',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0KIkxS3hprDuiDIqMHTfG9',
#    'duration_ms': 251493,
#    'time_signature': 4},
#   {'danceability': 0.599,
#    'energy': 0.837,
#    'key': 5,
#    'loudness': -4.045,
#    'mode': 0,
#    'speechiness': 0.0394,
#    'acousticness': 0.00684,
#    'instrumentalness': 6.93e-05,
#    'liveness': 0.104,
#    'valence': 0.561,
#    'tempo': 104.457,
#    'type': 'audio_features',
#    'id': '4zAjQDduJhIRFSpfrIN68Z',
#    'uri': 'spotify:track:4zAjQDduJhIRFSpfrIN68Z',
#    'track_href': 'https://api.spotify.com/v1/tracks/4zAjQDduJhIRFSpfrIN68Z',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4zAjQDduJhIRFSpfrIN68Z',
#    'duration_ms': 289907,
#    'time_signature': 4},
#   {'danceability': 0.451,
#    'energy': 0.822,
#    'key': 1,
#    'loudness': -5.788,
#    'mode': 0,
#    'speechiness': 0.0542,
#    'acousticness': 0.000399,
#    'instrumentalness': 0.000449,
#    'liveness': 0.153,
#    'valence': 0.524,
#    'tempo': 164.094,
#    'type': 'audio_features',
#    'id': '15niYbmRN5e6Hi3ZNVMUKN',
#    'uri': 'spotify:track:15niYbmRN5e6Hi3ZNVMUKN',
#    'track_href': 'https://api.spotify.com/v1/tracks/15niYbmRN5e6Hi3ZNVMUKN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/15niYbmRN5e6Hi3ZNVMUKN',
#    'duration_ms': 210965,
#    'time_signature': 4},
#   {'danceability': 0.533,
#    'energy': 0.967,
#    'key': 1,
#    'loudness': -2.543,
#    'mode': 1,
#    'speechiness': 0.0995,
#    'acousticness': 0.00791,
#    'instrumentalness': 0,
#    'liveness': 0.336,
#    'valence': 0.782,
#    'tempo': 142.018,
#    'type': 'audio_features',
#    'id': '4CbKVDZkYKdv69I4bCaKUq',
#    'uri': 'spotify:track:4CbKVDZkYKdv69I4bCaKUq',
#    'track_href': 'https://api.spotify.com/v1/tracks/4CbKVDZkYKdv69I4bCaKUq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4CbKVDZkYKdv69I4bCaKUq',
#    'duration_ms': 186813,
#    'time_signature': 4},
#   {'danceability': 0.32,
#    'energy': 0.91,
#    'key': 9,
#    'loudness': -5.321,
#    'mode': 1,
#    'speechiness': 0.114,
#    'acousticness': 0.000997,
#    'instrumentalness': 0,
#    'liveness': 0.16,
#    'valence': 0.22,
#    'tempo': 165.943,
#    'type': 'audio_features',
#    'id': '0DLjcGTmH2NV9AjzecAGT6',
#    'uri': 'spotify:track:0DLjcGTmH2NV9AjzecAGT6',
#    'track_href': 'https://api.spotify.com/v1/tracks/0DLjcGTmH2NV9AjzecAGT6',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0DLjcGTmH2NV9AjzecAGT6',
#    'duration_ms': 214373,
#    'time_signature': 4},
#   {'danceability': 0.535,
#    'energy': 0.979,
#    'key': 8,
#    'loudness': -3.593,
#    'mode': 1,
#    'speechiness': 0.0597,
#    'acousticness': 0.000666,
#    'instrumentalness': 0,
#    'liveness': 0.084,
#    'valence': 0.432,
#    'tempo': 103.996,
#    'type': 'audio_features',
#    'id': '5302m3J0HLANBaH3bCdDBb',
#    'uri': 'spotify:track:5302m3J0HLANBaH3bCdDBb',
#    'track_href': 'https://api.spotify.com/v1/tracks/5302m3J0HLANBaH3bCdDBb',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5302m3J0HLANBaH3bCdDBb',
#    'duration_ms': 238870,
#    'time_signature': 4},
#   {'danceability': 0.487,
#    'energy': 0.949,
#    'key': 2,
#    'loudness': -4.217,
#    'mode': 0,
#    'speechiness': 0.0798,
#    'acousticness': 0.000429,
#    'instrumentalness': 2.91e-05,
#    'liveness': 0.231,
#    'valence': 0.406,
#    'tempo': 110.02,
#    'type': 'audio_features',
#    'id': '7zAt4tdL44D3VuzsvM0N8n',
#    'uri': 'spotify:track:7zAt4tdL44D3VuzsvM0N8n',
#    'track_href': 'https://api.spotify.com/v1/tracks/7zAt4tdL44D3VuzsvM0N8n',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7zAt4tdL44D3VuzsvM0N8n',
#    'duration_ms': 352427,
#    'time_signature': 4},
#   {'danceability': 0.561,
#    'energy': 0.786,
#    'key': 1,
#    'loudness': -6.99,
#    'mode': 1,
#    'speechiness': 0.0298,
#    'acousticness': 0.00131,
#    'instrumentalness': 7.05e-05,
#    'liveness': 0.26,
#    'valence': 0.0907,
#    'tempo': 140.017,
#    'type': 'audio_features',
#    'id': '6QyBWey7P8ILuhS5RO7xYe',
#    'uri': 'spotify:track:6QyBWey7P8ILuhS5RO7xYe',
#    'track_href': 'https://api.spotify.com/v1/tracks/6QyBWey7P8ILuhS5RO7xYe',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6QyBWey7P8ILuhS5RO7xYe',
#    'duration_ms': 184520,
#    'time_signature': 4},
#   {'danceability': 0.414,
#    'energy': 0.95,
#    'key': 0,
#    'loudness': -3.303,
#    'mode': 0,
#    'speechiness': 0.112,
#    'acousticness': 6.42e-05,
#    'instrumentalness': 0.118,
#    'liveness': 0.12,
#    'valence': 0.34,
#    'tempo': 145.982,
#    'type': 'audio_features',
#    'id': '6yvmELWfw8hQa2wQZZjMdK',
#    'uri': 'spotify:track:6yvmELWfw8hQa2wQZZjMdK',
#    'track_href': 'https://api.spotify.com/v1/tracks/6yvmELWfw8hQa2wQZZjMdK',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yvmELWfw8hQa2wQZZjMdK',
#    'duration_ms': 204280,
#    'time_signature': 4},
#   {'danceability': 0.652,
#    'energy': 0.809,
#    'key': 6,
#    'loudness': -4.05,
#    'mode': 1,
#    'speechiness': 0.118,
#    'acousticness': 0.0267,
#    'instrumentalness': 0,
#    'liveness': 0.694,
#    'valence': 0.652,
#    'tempo': 129.957,
#    'type': 'audio_features',
#    'id': '305etOhoXSzF7UMOw90IFl',
#    'uri': 'spotify:track:305etOhoXSzF7UMOw90IFl',
#    'track_href': 'https://api.spotify.com/v1/tracks/305etOhoXSzF7UMOw90IFl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/305etOhoXSzF7UMOw90IFl',
#    'duration_ms': 216024,
#    'time_signature': 4},
#   {'danceability': 0.587,
#    'energy': 0.808,
#    'key': 9,
#    'loudness': -9.768,
#    'mode': 0,
#    'speechiness': 0.0641,
#    'acousticness': 0.000318,
#    'instrumentalness': 9.7e-05,
#    'liveness': 0.0619,
#    'valence': 0.343,
#    'tempo': 100.043,
#    'type': 'audio_features',
#    'id': '622xOPYk7gGofeA0cj8miF',
#    'uri': 'spotify:track:622xOPYk7gGofeA0cj8miF',
#    'track_href': 'https://api.spotify.com/v1/tracks/622xOPYk7gGofeA0cj8miF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/622xOPYk7gGofeA0cj8miF',
#    'duration_ms': 235200,
#    'time_signature': 4},
#   {'danceability': 0.505,
#    'energy': 0.964,
#    'key': 7,
#    'loudness': -3.673,
#    'mode': 1,
#    'speechiness': 0.0718,
#    'acousticness': 9.97e-05,
#    'instrumentalness': 2.85e-06,
#    'liveness': 0.113,
#    'valence': 0.571,
#    'tempo': 138.021,
#    'type': 'audio_features',
#    'id': '6WaYiQUPel70HUaCZj5eND',
#    'uri': 'spotify:track:6WaYiQUPel70HUaCZj5eND',
#    'track_href': 'https://api.spotify.com/v1/tracks/6WaYiQUPel70HUaCZj5eND',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6WaYiQUPel70HUaCZj5eND',
#    'duration_ms': 229773,
#    'time_signature': 4},
#   {'danceability': 0.465,
#    'energy': 0.813,
#    'key': 7,
#    'loudness': -4.321,
#    'mode': 1,
#    'speechiness': 0.0841,
#    'acousticness': 0.00281,
#    'instrumentalness': 0,
#    'liveness': 0.0464,
#    'valence': 0.614,
#    'tempo': 148.029,
#    'type': 'audio_features',
#    'id': '1RXoCep9hxApPfx8UFsGZk',
#    'uri': 'spotify:track:1RXoCep9hxApPfx8UFsGZk',
#    'track_href': 'https://api.spotify.com/v1/tracks/1RXoCep9hxApPfx8UFsGZk',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1RXoCep9hxApPfx8UFsGZk',
#    'duration_ms': 197373,
#    'time_signature': 4},
#   {'danceability': 0.469,
#    'energy': 0.983,
#    'key': 2,
#    'loudness': -3.635,
#    'mode': 1,
#    'speechiness': 0.186,
#    'acousticness': 0.000158,
#    'instrumentalness': 4.63e-05,
#    'liveness': 0.0566,
#    'valence': 0.119,
#    'tempo': 135.094,
#    'type': 'audio_features',
#    'id': '3fudNa8fr0Hk1cgKvz2FtZ',
#    'uri': 'spotify:track:3fudNa8fr0Hk1cgKvz2FtZ',
#    'track_href': 'https://api.spotify.com/v1/tracks/3fudNa8fr0Hk1cgKvz2FtZ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3fudNa8fr0Hk1cgKvz2FtZ',
#    'duration_ms': 255067,
#    'time_signature': 4},
#   {'danceability': 0.575,
#    'energy': 0.957,
#    'key': 10,
#    'loudness': -3.534,
#    'mode': 1,
#    'speechiness': 0.0969,
#    'acousticness': 0.00699,
#    'instrumentalness': 0,
#    'liveness': 0.511,
#    'valence': 0.309,
#    'tempo': 128.015,
#    'type': 'audio_features',
#    'id': '5ABl9GeMcWog9Yrur3P9Jq',
#    'uri': 'spotify:track:5ABl9GeMcWog9Yrur3P9Jq',
#    'track_href': 'https://api.spotify.com/v1/tracks/5ABl9GeMcWog9Yrur3P9Jq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ABl9GeMcWog9Yrur3P9Jq',
#    'duration_ms': 257469,
#    'time_signature': 4},
#   {'danceability': 0.32,
#    'energy': 0.947,
#    'key': 2,
#    'loudness': -3.918,
#    'mode': 1,
#    'speechiness': 0.152,
#    'acousticness': 2.04e-05,
#    'instrumentalness': 0,
#    'liveness': 0.31,
#    'valence': 0.471,
#    'tempo': 134.099,
#    'type': 'audio_features',
#    'id': '5sxSfajurxK1jzBUzTLou5',
#    'uri': 'spotify:track:5sxSfajurxK1jzBUzTLou5',
#    'track_href': 'https://api.spotify.com/v1/tracks/5sxSfajurxK1jzBUzTLou5',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5sxSfajurxK1jzBUzTLou5',
#    'duration_ms': 238169,
#    'time_signature': 4},
#   {'danceability': 0.316,
#    'energy': 0.729,
#    'key': 2,
#    'loudness': -5.931,
#    'mode': 0,
#    'speechiness': 0.0356,
#    'acousticness': 0.0203,
#    'instrumentalness': 8.99e-06,
#    'liveness': 0.207,
#    'valence': 0.367,
#    'tempo': 163.127,
#    'type': 'audio_features',
#    'id': '7MOQrtXMNImAq5TrPZzC0w',
#    'uri': 'spotify:track:7MOQrtXMNImAq5TrPZzC0w',
#    'track_href': 'https://api.spotify.com/v1/tracks/7MOQrtXMNImAq5TrPZzC0w',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MOQrtXMNImAq5TrPZzC0w',
#    'duration_ms': 251533,
#    'time_signature': 4},
#   {'danceability': 0.494,
#    'energy': 0.818,
#    'key': 1,
#    'loudness': -6.025,
#    'mode': 0,
#    'speechiness': 0.0367,
#    'acousticness': 7.48e-05,
#    'instrumentalness': 0.129,
#    'liveness': 0.0592,
#    'valence': 0.169,
#    'tempo': 111.932,
#    'type': 'audio_features',
#    'id': '0dWy5gz8IwvIyJEHOPKwKU',
#    'uri': 'spotify:track:0dWy5gz8IwvIyJEHOPKwKU',
#    'track_href': 'https://api.spotify.com/v1/tracks/0dWy5gz8IwvIyJEHOPKwKU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0dWy5gz8IwvIyJEHOPKwKU',
#    'duration_ms': 338440,
#    'time_signature': 4},
#   {'danceability': 0.359,
#    'energy': 0.955,
#    'key': 4,
#    'loudness': -2.323,
#    'mode': 0,
#    'speechiness': 0.12,
#    'acousticness': 0.00116,
#    'instrumentalness': 0,
#    'liveness': 0.349,
#    'valence': 0.446,
#    'tempo': 170.033,
#    'type': 'audio_features',
#    'id': '5pRElcsPZrgZXkoON2o5Go',
#    'uri': 'spotify:track:5pRElcsPZrgZXkoON2o5Go',
#    'track_href': 'https://api.spotify.com/v1/tracks/5pRElcsPZrgZXkoON2o5Go',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5pRElcsPZrgZXkoON2o5Go',
#    'duration_ms': 230427,
#    'time_signature': 4},
#   {'danceability': 0.629,
#    'energy': 0.933,
#    'key': 8,
#    'loudness': -3.051,
#    'mode': 1,
#    'speechiness': 0.0693,
#    'acousticness': 0.00389,
#    'instrumentalness': 0,
#    'liveness': 0.114,
#    'valence': 0.589,
#    'tempo': 127.0,
#    'type': 'audio_features',
#    'id': '3gtdftgbnka6cCfRz6SKjE',
#    'uri': 'spotify:track:3gtdftgbnka6cCfRz6SKjE',
#    'track_href': 'https://api.spotify.com/v1/tracks/3gtdftgbnka6cCfRz6SKjE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3gtdftgbnka6cCfRz6SKjE',
#    'duration_ms': 190360,
#    'time_signature': 4},
#   {'danceability': 0.509,
#    'energy': 0.938,
#    'key': 11,
#    'loudness': -3.883,
#    'mode': 0,
#    'speechiness': 0.0715,
#    'acousticness': 0.000644,
#    'instrumentalness': 0.00246,
#    'liveness': 0.14,
#    'valence': 0.335,
#    'tempo': 94.019,
#    'type': 'audio_features',
#    'id': '6rSuL1ViLO7Aljn2WD09s4',
#    'uri': 'spotify:track:6rSuL1ViLO7Aljn2WD09s4',
#    'track_href': 'https://api.spotify.com/v1/tracks/6rSuL1ViLO7Aljn2WD09s4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6rSuL1ViLO7Aljn2WD09s4',
#    'duration_ms': 204347,
#    'time_signature': 4},
#   {'danceability': 0.394,
#    'energy': 0.878,
#    'key': 2,
#    'loudness': -3.418,
#    'mode': 1,
#    'speechiness': 0.0696,
#    'acousticness': 0.000284,
#    'instrumentalness': 0,
#    'liveness': 0.0583,
#    'valence': 0.592,
#    'tempo': 176.173,
#    'type': 'audio_features',
#    'id': '2stwPgrh5NpNr8PdiIPEhE',
#    'uri': 'spotify:track:2stwPgrh5NpNr8PdiIPEhE',
#    'track_href': 'https://api.spotify.com/v1/tracks/2stwPgrh5NpNr8PdiIPEhE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2stwPgrh5NpNr8PdiIPEhE',
#    'duration_ms': 237733,
#    'time_signature': 4},
#   {'danceability': 0.358,
#    'energy': 0.856,
#    'key': 2,
#    'loudness': -2.934,
#    'mode': 1,
#    'speechiness': 0.0471,
#    'acousticness': 0.0253,
#    'instrumentalness': 0,
#    'liveness': 0.233,
#    'valence': 0.542,
#    'tempo': 169.81,
#    'type': 'audio_features',
#    'id': '37CMjUAU8fL6YqZVTplZqZ',
#    'uri': 'spotify:track:37CMjUAU8fL6YqZVTplZqZ',
#    'track_href': 'https://api.spotify.com/v1/tracks/37CMjUAU8fL6YqZVTplZqZ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/37CMjUAU8fL6YqZVTplZqZ',
#    'duration_ms': 210787,
#    'time_signature': 4},
#   {'danceability': 0.217,
#    'energy': 0.763,
#    'key': 10,
#    'loudness': -4.024,
#    'mode': 1,
#    'speechiness': 0.0426,
#    'acousticness': 0.00144,
#    'instrumentalness': 1.59e-05,
#    'liveness': 0.238,
#    'valence': 0.342,
#    'tempo': 86.7,
#    'type': 'audio_features',
#    'id': '4emQrNiz37OidY7SoXXQls',
#    'uri': 'spotify:track:4emQrNiz37OidY7SoXXQls',
#    'track_href': 'https://api.spotify.com/v1/tracks/4emQrNiz37OidY7SoXXQls',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4emQrNiz37OidY7SoXXQls',
#    'duration_ms': 245716,
#    'time_signature': 3},
#   {'danceability': 0.351,
#    'energy': 0.944,
#    'key': 5,
#    'loudness': -3.71,
#    'mode': 1,
#    'speechiness': 0.12,
#    'acousticness': 0.000249,
#    'instrumentalness': 0.00218,
#    'liveness': 0.0678,
#    'valence': 0.428,
#    'tempo': 187.736,
#    'type': 'audio_features',
#    'id': '0mlAENRIsoWbxbIQnZP7m5',
#    'uri': 'spotify:track:0mlAENRIsoWbxbIQnZP7m5',
#    'track_href': 'https://api.spotify.com/v1/tracks/0mlAENRIsoWbxbIQnZP7m5',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0mlAENRIsoWbxbIQnZP7m5',
#    'duration_ms': 252453,
#    'time_signature': 4},
#   {'danceability': 0.548,
#    'energy': 0.924,
#    'key': 11,
#    'loudness': -4.48,
#    'mode': 0,
#    'speechiness': 0.0689,
#    'acousticness': 0.00033,
#    'instrumentalness': 1.42e-05,
#    'liveness': 0.162,
#    'valence': 0.242,
#    'tempo': 124.031,
#    'type': 'audio_features',
#    'id': '2pYaGdqXBrl8MdvuwgtBb7',
#    'uri': 'spotify:track:2pYaGdqXBrl8MdvuwgtBb7',
#    'track_href': 'https://api.spotify.com/v1/tracks/2pYaGdqXBrl8MdvuwgtBb7',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2pYaGdqXBrl8MdvuwgtBb7',
#    'duration_ms': 244538,
#    'time_signature': 4},
#   {'danceability': 0.254,
#    'energy': 0.941,
#    'key': 9,
#    'loudness': -4.022,
#    'mode': 1,
#    'speechiness': 0.17,
#    'acousticness': 5.22e-05,
#    'instrumentalness': 5.34e-06,
#    'liveness': 0.131,
#    'valence': 0.251,
#    'tempo': 95.252,
#    'type': 'audio_features',
#    'id': '3HJrZyx3srOSpqp88Jp3wF',
#    'uri': 'spotify:track:3HJrZyx3srOSpqp88Jp3wF',
#    'track_href': 'https://api.spotify.com/v1/tracks/3HJrZyx3srOSpqp88Jp3wF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3HJrZyx3srOSpqp88Jp3wF',
#    'duration_ms': 300773,
#    'time_signature': 4},
#   {'danceability': 0.478,
#    'energy': 0.949,
#    'key': 11,
#    'loudness': -3.383,
#    'mode': 1,
#    'speechiness': 0.0732,
#    'acousticness': 0.00055,
#    'instrumentalness': 0,
#    'liveness': 0.204,
#    'valence': 0.223,
#    'tempo': 104.937,
#    'type': 'audio_features',
#    'id': '1Y9fmfIMMrJLm9c8fQKvDw',
#    'uri': 'spotify:track:1Y9fmfIMMrJLm9c8fQKvDw',
#    'track_href': 'https://api.spotify.com/v1/tracks/1Y9fmfIMMrJLm9c8fQKvDw',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Y9fmfIMMrJLm9c8fQKvDw',
#    'duration_ms': 238413,
#    'time_signature': 4},
#   {'danceability': 0.443,
#    'energy': 0.9,
#    'key': 11,
#    'loudness': -3.329,
#    'mode': 0,
#    'speechiness': 0.052,
#    'acousticness': 3.68e-05,
#    'instrumentalness': 0.617,
#    'liveness': 0.11,
#    'valence': 0.476,
#    'tempo': 160.006,
#    'type': 'audio_features',
#    'id': '3YUFV2DmZaGNTikLnO6mIB',
#    'uri': 'spotify:track:3YUFV2DmZaGNTikLnO6mIB',
#    'track_href': 'https://api.spotify.com/v1/tracks/3YUFV2DmZaGNTikLnO6mIB',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3YUFV2DmZaGNTikLnO6mIB',
#    'duration_ms': 276630,
#    'time_signature': 4},
#   {'danceability': 0.508,
#    'energy': 0.92,
#    'key': 5,
#    'loudness': -3.264,
#    'mode': 1,
#    'speechiness': 0.045,
#    'acousticness': 0.000589,
#    'instrumentalness': 2.71e-06,
#    'liveness': 0.107,
#    'valence': 0.301,
#    'tempo': 102.989,
#    'type': 'audio_features',
#    'id': '3PwUxOBMBkwILa7Y0s6h8S',
#    'uri': 'spotify:track:3PwUxOBMBkwILa7Y0s6h8S',
#    'track_href': 'https://api.spotify.com/v1/tracks/3PwUxOBMBkwILa7Y0s6h8S',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3PwUxOBMBkwILa7Y0s6h8S',
#    'duration_ms': 273627,
#    'time_signature': 4},
#   {'danceability': 0.483,
#    'energy': 0.941,
#    'key': 2,
#    'loudness': -3.598,
#    'mode': 0,
#    'speechiness': 0.0575,
#    'acousticness': 0.000526,
#    'instrumentalness': 3.5e-06,
#    'liveness': 0.31,
#    'valence': 0.503,
#    'tempo': 156.033,
#    'type': 'audio_features',
#    'id': '5O9Dz0h08LuBi0aVvDcylh',
#    'uri': 'spotify:track:5O9Dz0h08LuBi0aVvDcylh',
#    'track_href': 'https://api.spotify.com/v1/tracks/5O9Dz0h08LuBi0aVvDcylh',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5O9Dz0h08LuBi0aVvDcylh',
#    'duration_ms': 232067,
#    'time_signature': 4},
#   {'danceability': 0.452,
#    'energy': 0.962,
#    'key': 11,
#    'loudness': -3.063,
#    'mode': 0,
#    'speechiness': 0.0831,
#    'acousticness': 0.00901,
#    'instrumentalness': 0,
#    'liveness': 0.065,
#    'valence': 0.566,
#    'tempo': 164.032,
#    'type': 'audio_features',
#    'id': '4Ahphc0UzRSoMpJRHgnGQK',
#    'uri': 'spotify:track:4Ahphc0UzRSoMpJRHgnGQK',
#    'track_href': 'https://api.spotify.com/v1/tracks/4Ahphc0UzRSoMpJRHgnGQK',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4Ahphc0UzRSoMpJRHgnGQK',
#    'duration_ms': 208827,
#    'time_signature': 4},
#   {'danceability': 0.39,
#    'energy': 0.884,
#    'key': 10,
#    'loudness': -4.345,
#    'mode': 0,
#    'speechiness': 0.0739,
#    'acousticness': 0.000902,
#    'instrumentalness': 1.56e-06,
#    'liveness': 0.111,
#    'valence': 0.346,
#    'tempo': 158.062,
#    'type': 'audio_features',
#    'id': '3JQiVDSCHiYdv8r0IV7UHG',
#    'uri': 'spotify:track:3JQiVDSCHiYdv8r0IV7UHG',
#    'track_href': 'https://api.spotify.com/v1/tracks/3JQiVDSCHiYdv8r0IV7UHG',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3JQiVDSCHiYdv8r0IV7UHG',
#    'duration_ms': 245573,
#    'time_signature': 4},
#   {'danceability': 0.434,
#    'energy': 0.939,
#    'key': 4,
#    'loudness': -2.983,
#    'mode': 0,
#    'speechiness': 0.0593,
#    'acousticness': 0.0425,
#    'instrumentalness': 0,
#    'liveness': 0.491,
#    'valence': 0.569,
#    'tempo': 159.932,
#    'type': 'audio_features',
#    'id': '0nkzd3yNniB767zSDDdLZ3',
#    'uri': 'spotify:track:0nkzd3yNniB767zSDDdLZ3',
#    'track_href': 'https://api.spotify.com/v1/tracks/0nkzd3yNniB767zSDDdLZ3',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0nkzd3yNniB767zSDDdLZ3',
#    'duration_ms': 209493,
#    'time_signature': 4},
#   {'danceability': 0.479,
#    'energy': 0.864,
#    'key': 5,
#    'loudness': -2.706,
#    'mode': 0,
#    'speechiness': 0.0366,
#    'acousticness': 3.25e-05,
#    'instrumentalness': 0.0215,
#    'liveness': 0.0751,
#    'valence': 0.403,
#    'tempo': 97.028,
#    'type': 'audio_features',
#    'id': '3bZl8Bdli5TPZH3CaGfMrN',
#    'uri': 'spotify:track:3bZl8Bdli5TPZH3CaGfMrN',
#    'track_href': 'https://api.spotify.com/v1/tracks/3bZl8Bdli5TPZH3CaGfMrN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3bZl8Bdli5TPZH3CaGfMrN',
#    'duration_ms': 213831,
#    'time_signature': 4},
#   {'danceability': 0.519,
#    'energy': 0.971,
#    'key': 7,
#    'loudness': -3.403,
#    'mode': 1,
#    'speechiness': 0.0977,
#    'acousticness': 0.00424,
#    'instrumentalness': 6.26e-06,
#    'liveness': 0.651,
#    'valence': 0.49,
#    'tempo': 138.059,
#    'type': 'audio_features',
#    'id': '7y7ZpEFZHr0jvSxvWFQ9d2',
#    'uri': 'spotify:track:7y7ZpEFZHr0jvSxvWFQ9d2',
#    'track_href': 'https://api.spotify.com/v1/tracks/7y7ZpEFZHr0jvSxvWFQ9d2',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7y7ZpEFZHr0jvSxvWFQ9d2',
#    'duration_ms': 271933,
#    'time_signature': 4},
#   {'danceability': 0.566,
#    'energy': 0.948,
#    'key': 9,
#    'loudness': -6.034,
#    'mode': 1,
#    'speechiness': 0.108,
#    'acousticness': 0.000113,
#    'instrumentalness': 7.05e-05,
#    'liveness': 0.0739,
#    'valence': 0.328,
#    'tempo': 138.483,
#    'type': 'audio_features',
#    'id': '5I3uzipgkLTYTDkeRtp769',
#    'uri': 'spotify:track:5I3uzipgkLTYTDkeRtp769',
#    'track_href': 'https://api.spotify.com/v1/tracks/5I3uzipgkLTYTDkeRtp769',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5I3uzipgkLTYTDkeRtp769',
#    'duration_ms': 286333,
#    'time_signature': 4},
#   {'danceability': 0.373,
#    'energy': 0.939,
#    'key': 1,
#    'loudness': -3.153,
#    'mode': 0,
#    'speechiness': 0.0603,
#    'acousticness': 0.00677,
#    'instrumentalness': 0,
#    'liveness': 0.137,
#    'valence': 0.429,
#    'tempo': 176.022,
#    'type': 'audio_features',
#    'id': '1OG0QQa2zZe4QeFwVhCiiA',
#    'uri': 'spotify:track:1OG0QQa2zZe4QeFwVhCiiA',
#    'track_href': 'https://api.spotify.com/v1/tracks/1OG0QQa2zZe4QeFwVhCiiA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1OG0QQa2zZe4QeFwVhCiiA',
#    'duration_ms': 233293,
#    'time_signature': 4},
#   {'danceability': 0.57,
#    'energy': 0.921,
#    'key': 4,
#    'loudness': -3.892,
#    'mode': 0,
#    'speechiness': 0.0724,
#    'acousticness': 0.0127,
#    'instrumentalness': 0,
#    'liveness': 0.818,
#    'valence': 0.381,
#    'tempo': 87.938,
#    'type': 'audio_features',
#    'id': '16SytZztRqKXcBuxA4aCKa',
#    'uri': 'spotify:track:16SytZztRqKXcBuxA4aCKa',
#    'track_href': 'https://api.spotify.com/v1/tracks/16SytZztRqKXcBuxA4aCKa',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/16SytZztRqKXcBuxA4aCKa',
#    'duration_ms': 260787,
#    'time_signature': 4},
#   {'danceability': 0.445,
#    'energy': 0.953,
#    'key': 5,
#    'loudness': -2.463,
#    'mode': 0,
#    'speechiness': 0.0704,
#    'acousticness': 0.0106,
#    'instrumentalness': 0,
#    'liveness': 0.281,
#    'valence': 0.475,
#    'tempo': 172.063,
#    'type': 'audio_features',
#    'id': '2jfk3m8nq5IvB35s2xIs1O',
#    'uri': 'spotify:track:2jfk3m8nq5IvB35s2xIs1O',
#    'track_href': 'https://api.spotify.com/v1/tracks/2jfk3m8nq5IvB35s2xIs1O',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2jfk3m8nq5IvB35s2xIs1O',
#    'duration_ms': 225280,
#    'time_signature': 4},
#   {'danceability': 0.478,
#    'energy': 0.816,
#    'key': 11,
#    'loudness': -4.288,
#    'mode': 1,
#    'speechiness': 0.0451,
#    'acousticness': 0.00165,
#    'instrumentalness': 0,
#    'liveness': 0.356,
#    'valence': 0.264,
#    'tempo': 75.959,
#    'type': 'audio_features',
#    'id': '6wGzrGwqJKQ7PW3wh04ZYo',
#    'uri': 'spotify:track:6wGzrGwqJKQ7PW3wh04ZYo',
#    'track_href': 'https://api.spotify.com/v1/tracks/6wGzrGwqJKQ7PW3wh04ZYo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6wGzrGwqJKQ7PW3wh04ZYo',
#    'duration_ms': 225468,
#    'time_signature': 4},
#   {'danceability': 0.574,
#    'energy': 0.947,
#    'key': 7,
#    'loudness': -6.358,
#    'mode': 1,
#    'speechiness': 0.14,
#    'acousticness': 0.000448,
#    'instrumentalness': 0.000373,
#    'liveness': 0.0655,
#    'valence': 0.428,
#    'tempo': 153.299,
#    'type': 'audio_features',
#    'id': '11FxjT3vYmYG4dgVS7VHPW',
#    'uri': 'spotify:track:11FxjT3vYmYG4dgVS7VHPW',
#    'track_href': 'https://api.spotify.com/v1/tracks/11FxjT3vYmYG4dgVS7VHPW',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/11FxjT3vYmYG4dgVS7VHPW',
#    'duration_ms': 246840,
#    'time_signature': 4},
#   {'danceability': 0.22,
#    'energy': 0.754,
#    'key': 8,
#    'loudness': -5.095,
#    'mode': 1,
#    'speechiness': 0.0594,
#    'acousticness': 0.0063,
#    'instrumentalness': 0,
#    'liveness': 0.0865,
#    'valence': 0.358,
#    'tempo': 160.126,
#    'type': 'audio_features',
#    'id': '6EwnYm73XEibpAPOnTc8li',
#    'uri': 'spotify:track:6EwnYm73XEibpAPOnTc8li',
#    'track_href': 'https://api.spotify.com/v1/tracks/6EwnYm73XEibpAPOnTc8li',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6EwnYm73XEibpAPOnTc8li',
#    'duration_ms': 216800,
#    'time_signature': 3},
#   {'danceability': 0.49,
#    'energy': 0.695,
#    'key': 0,
#    'loudness': -2.961,
#    'mode': 1,
#    'speechiness': 0.0382,
#    'acousticness': 0.612,
#    'instrumentalness': 0,
#    'liveness': 0.0995,
#    'valence': 0.394,
#    'tempo': 121.924,
#    'type': 'audio_features',
#    'id': '1l02bWKcH8WdOmyoE3E5Gc',
#    'uri': 'spotify:track:1l02bWKcH8WdOmyoE3E5Gc',
#    'track_href': 'https://api.spotify.com/v1/tracks/1l02bWKcH8WdOmyoE3E5Gc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1l02bWKcH8WdOmyoE3E5Gc',
#    'duration_ms': 174124,
#    'time_signature': 4},
#   {'danceability': 0.609,
#    'energy': 0.892,
#    'key': 0,
#    'loudness': -4.775,
#    'mode': 1,
#    'speechiness': 0.0812,
#    'acousticness': 0.000203,
#    'instrumentalness': 0,
#    'liveness': 0.0526,
#    'valence': 0.462,
#    'tempo': 123.828,
#    'type': 'audio_features',
#    'id': '4uAoGnYtLYdDTCNxG6liOJ',
#    'uri': 'spotify:track:4uAoGnYtLYdDTCNxG6liOJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/4uAoGnYtLYdDTCNxG6liOJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4uAoGnYtLYdDTCNxG6liOJ',
#    'duration_ms': 215893,
#    'time_signature': 4},
#   {'danceability': 0.528,
#    'energy': 0.941,
#    'key': 1,
#    'loudness': -5.452,
#    'mode': 1,
#    'speechiness': 0.0827,
#    'acousticness': 0.00035,
#    'instrumentalness': 0,
#    'liveness': 0.0777,
#    'valence': 0.292,
#    'tempo': 112.991,
#    'type': 'audio_features',
#    'id': '3Lac7ElVdBqRsLdGEHLHFN',
#    'uri': 'spotify:track:3Lac7ElVdBqRsLdGEHLHFN',
#    'track_href': 'https://api.spotify.com/v1/tracks/3Lac7ElVdBqRsLdGEHLHFN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Lac7ElVdBqRsLdGEHLHFN',
#    'duration_ms': 306733,
#    'time_signature': 4},
#   {'danceability': 0.489,
#    'energy': 0.783,
#    'key': 7,
#    'loudness': -5.64,
#    'mode': 0,
#    'speechiness': 0.0384,
#    'acousticness': 0.0425,
#    'instrumentalness': 2.98e-06,
#    'liveness': 0.252,
#    'valence': 0.259,
#    'tempo': 151.922,
#    'type': 'audio_features',
#    'id': '6i9G9jq9O2M11W7vPsL7jm',
#    'uri': 'spotify:track:6i9G9jq9O2M11W7vPsL7jm',
#    'track_href': 'https://api.spotify.com/v1/tracks/6i9G9jq9O2M11W7vPsL7jm',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6i9G9jq9O2M11W7vPsL7jm',
#    'duration_ms': 289667,
#    'time_signature': 4},
#   {'danceability': 0.501,
#    'energy': 0.942,
#    'key': 4,
#    'loudness': -3.127,
#    'mode': 0,
#    'speechiness': 0.0905,
#    'acousticness': 0.00197,
#    'instrumentalness': 0,
#    'liveness': 0.182,
#    'valence': 0.461,
#    'tempo': 92.967,
#    'type': 'audio_features',
#    'id': '4AVxmpwfXH7p4YyTbg9nS4',
#    'uri': 'spotify:track:4AVxmpwfXH7p4YyTbg9nS4',
#    'track_href': 'https://api.spotify.com/v1/tracks/4AVxmpwfXH7p4YyTbg9nS4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4AVxmpwfXH7p4YyTbg9nS4',
#    'duration_ms': 210027,
#    'time_signature': 4},
#   {'danceability': 0.365,
#    'energy': 0.951,
#    'key': 0,
#    'loudness': -3.34,
#    'mode': 1,
#    'speechiness': 0.079,
#    'acousticness': 0.023,
#    'instrumentalness': 0,
#    'liveness': 0.147,
#    'valence': 0.455,
#    'tempo': 174.096,
#    'type': 'audio_features',
#    'id': '1ZWEsoqJSrtZA1qjlG02Hp',
#    'uri': 'spotify:track:1ZWEsoqJSrtZA1qjlG02Hp',
#    'track_href': 'https://api.spotify.com/v1/tracks/1ZWEsoqJSrtZA1qjlG02Hp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ZWEsoqJSrtZA1qjlG02Hp',
#    'duration_ms': 226507,
#    'time_signature': 4},
#   {'danceability': 0.572,
#    'energy': 0.991,
#    'key': 2,
#    'loudness': -3.26,
#    'mode': 1,
#    'speechiness': 0.056,
#    'acousticness': 0.00263,
#    'instrumentalness': 0,
#    'liveness': 0.402,
#    'valence': 0.704,
#    'tempo': 128.049,
#    'type': 'audio_features',
#    'id': '0xdHxI8iKatXB8PYWKRi74',
#    'uri': 'spotify:track:0xdHxI8iKatXB8PYWKRi74',
#    'track_href': 'https://api.spotify.com/v1/tracks/0xdHxI8iKatXB8PYWKRi74',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0xdHxI8iKatXB8PYWKRi74',
#    'duration_ms': 231106,
#    'time_signature': 4},
#   {'danceability': 0.466,
#    'energy': 0.928,
#    'key': 9,
#    'loudness': -2.59,
#    'mode': 0,
#    'speechiness': 0.0657,
#    'acousticness': 0.0518,
#    'instrumentalness': 1.16e-06,
#    'liveness': 0.0629,
#    'valence': 0.711,
#    'tempo': 168.026,
#    'type': 'audio_features',
#    'id': '51FcyG2zVvHolj5rx5r2Ii',
#    'uri': 'spotify:track:51FcyG2zVvHolj5rx5r2Ii',
#    'track_href': 'https://api.spotify.com/v1/tracks/51FcyG2zVvHolj5rx5r2Ii',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/51FcyG2zVvHolj5rx5r2Ii',
#    'duration_ms': 199480,
#    'time_signature': 4},
#   {'danceability': 0.456,
#    'energy': 0.87,
#    'key': 4,
#    'loudness': -3.771,
#    'mode': 1,
#    'speechiness': 0.0442,
#    'acousticness': 0.0321,
#    'instrumentalness': 1.21e-05,
#    'liveness': 0.0948,
#    'valence': 0.529,
#    'tempo': 161.963,
#    'type': 'audio_features',
#    'id': '6UjAK23BouDme1ZhpjBOcJ',
#    'uri': 'spotify:track:6UjAK23BouDme1ZhpjBOcJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/6UjAK23BouDme1ZhpjBOcJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6UjAK23BouDme1ZhpjBOcJ',
#    'duration_ms': 206933,
#    'time_signature': 4},
#   {'danceability': 0.47,
#    'energy': 0.836,
#    'key': 9,
#    'loudness': -4.348,
#    'mode': 0,
#    'speechiness': 0.0349,
#    'acousticness': 0.0217,
#    'instrumentalness': 0,
#    'liveness': 0.331,
#    'valence': 0.412,
#    'tempo': 135.955,
#    'type': 'audio_features',
#    'id': '3h4JgBHcWM7A4CBVI6csau',
#    'uri': 'spotify:track:3h4JgBHcWM7A4CBVI6csau',
#    'track_href': 'https://api.spotify.com/v1/tracks/3h4JgBHcWM7A4CBVI6csau',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3h4JgBHcWM7A4CBVI6csau',
# ...
#   {'danceability': 0.679,
#    'energy': 0.442,
#    'key': 1,
#    'loudness': -12.132,
#    'mode': 1,
#    'speechiness': 0.0364,
#    'acousticness': 0.00703,
#    'instrumentalness': 0.777,
#    'liveness': 0.194,
#    'valence': 0.397,
#    'tempo': 109.991,
#    'type': 'audio_features',
#    'id': '0iuG66au8jlBoY2Polrp2D',
#    'uri': 'spotify:track:0iuG66au8jlBoY2Polrp2D',
#    'track_href': 'https://api.spotify.com/v1/tracks/0iuG66au8jlBoY2Polrp2D',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0iuG66au8jlBoY2Polrp2D',
#    'duration_ms': 319574,
#    'time_signature': 4},
#   {'danceability': 0.768,
#    'energy': 0.565,
#    'key': 2,
#    'loudness': -11.863,
#    'mode': 1,
#    'speechiness': 0.0904,
#    'acousticness': 0.184,
#    'instrumentalness': 0.331,
#    'liveness': 0.0808,
#    'valence': 0.436,
#    'tempo': 179.962,
#    'type': 'audio_features',
#    'id': '7eIAszvtf0uX1WjS4EsNRq',
#    'uri': 'spotify:track:7eIAszvtf0uX1WjS4EsNRq',
#    'track_href': 'https://api.spotify.com/v1/tracks/7eIAszvtf0uX1WjS4EsNRq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7eIAszvtf0uX1WjS4EsNRq',
#    'duration_ms': 234259,
#    'time_signature': 4},
#   {'danceability': 0.443,
#    'energy': 0.218,
#    'key': 1,
#    'loudness': -12.165,
#    'mode': 1,
#    'speechiness': 0.0294,
#    'acousticness': 0.7,
#    'instrumentalness': 0.000115,
#    'liveness': 0.0993,
#    'valence': 0.262,
#    'tempo': 133.783,
#    'type': 'audio_features',
#    'id': '43PZPK2GuhI0vKoxR6X2GA',
#    'uri': 'spotify:track:43PZPK2GuhI0vKoxR6X2GA',
#    'track_href': 'https://api.spotify.com/v1/tracks/43PZPK2GuhI0vKoxR6X2GA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43PZPK2GuhI0vKoxR6X2GA',
#    'duration_ms': 352240,
#    'time_signature': 4},
#   {'danceability': 0.731,
#    'energy': 0.597,
#    'key': 4,
#    'loudness': -7.661,
#    'mode': 1,
#    'speechiness': 0.0567,
#    'acousticness': 0.338,
#    'instrumentalness': 0.00114,
#    'liveness': 0.0771,
#    'valence': 0.863,
#    'tempo': 101.991,
#    'type': 'audio_features',
#    'id': '5V7qLbZJNTwaEVbZADqofc',
#    'uri': 'spotify:track:5V7qLbZJNTwaEVbZADqofc',
#    'track_href': 'https://api.spotify.com/v1/tracks/5V7qLbZJNTwaEVbZADqofc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5V7qLbZJNTwaEVbZADqofc',
#    'duration_ms': 159013,
#    'time_signature': 4},
#   {'danceability': 0.459,
#    'energy': 0.214,
#    'key': 5,
#    'loudness': -10.66,
#    'mode': 1,
#    'speechiness': 0.0403,
#    'acousticness': 0.634,
#    'instrumentalness': 0,
#    'liveness': 0.125,
#    'valence': 0.397,
#    'tempo': 163.816,
#    'type': 'audio_features',
#    'id': '4edtsBlaX23OPYmhA4R0GP',
#    'uri': 'spotify:track:4edtsBlaX23OPYmhA4R0GP',
#    'track_href': 'https://api.spotify.com/v1/tracks/4edtsBlaX23OPYmhA4R0GP',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4edtsBlaX23OPYmhA4R0GP',
#    'duration_ms': 179013,
#    'time_signature': 4},
#   {'danceability': 0.761,
#    'energy': 0.565,
#    'key': 11,
#    'loudness': -7.016,
#    'mode': 0,
#    'speechiness': 0.0411,
#    'acousticness': 0.345,
#    'instrumentalness': 0,
#    'liveness': 0.0825,
#    'valence': 0.583,
#    'tempo': 105.008,
#    'type': 'audio_features',
#    'id': '1a1LrfgkTvfHFykIxcv8WU',
#    'uri': 'spotify:track:1a1LrfgkTvfHFykIxcv8WU',
#    'track_href': 'https://api.spotify.com/v1/tracks/1a1LrfgkTvfHFykIxcv8WU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1a1LrfgkTvfHFykIxcv8WU',
#    'duration_ms': 173286,
#    'time_signature': 4},
#   {'danceability': 0.796,
#    'energy': 0.459,
#    'key': 8,
#    'loudness': -7.716,
#    'mode': 0,
#    'speechiness': 0.0443,
#    'acousticness': 0.705,
#    'instrumentalness': 1.15e-05,
#    'liveness': 0.0605,
#    'valence': 0.767,
#    'tempo': 88.0,
#    'type': 'audio_features',
#    'id': '0loJyuSFr6vVPBQSmLLrrQ',
#    'uri': 'spotify:track:0loJyuSFr6vVPBQSmLLrrQ',
#    'track_href': 'https://api.spotify.com/v1/tracks/0loJyuSFr6vVPBQSmLLrrQ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0loJyuSFr6vVPBQSmLLrrQ',
#    'duration_ms': 197082,
#    'time_signature': 4},
#   {'danceability': 0.708,
#    'energy': 0.47,
#    'key': 9,
#    'loudness': -7.59,
#    'mode': 1,
#    'speechiness': 0.0659,
#    'acousticness': 0.248,
#    'instrumentalness': 0,
#    'liveness': 0.0852,
#    'valence': 0.536,
#    'tempo': 82.007,
#    'type': 'audio_features',
#    'id': '39afswHs17v53znQm1gDTY',
#    'uri': 'spotify:track:39afswHs17v53znQm1gDTY',
#    'track_href': 'https://api.spotify.com/v1/tracks/39afswHs17v53znQm1gDTY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/39afswHs17v53znQm1gDTY',
#    'duration_ms': 229413,
#    'time_signature': 4},
#   {'danceability': 0.67,
#    'energy': 0.354,
#    'key': 7,
#    'loudness': -12.587,
#    'mode': 1,
#    'speechiness': 0.0326,
#    'acousticness': 0.698,
#    'instrumentalness': 0.000166,
#    'liveness': 0.109,
#    'valence': 0.33,
#    'tempo': 127.136,
#    'type': 'audio_features',
#    'id': '4fi9IIcjYzxRTRwJUyFO6Q',
#    'uri': 'spotify:track:4fi9IIcjYzxRTRwJUyFO6Q',
#    'track_href': 'https://api.spotify.com/v1/tracks/4fi9IIcjYzxRTRwJUyFO6Q',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4fi9IIcjYzxRTRwJUyFO6Q',
#    'duration_ms': 249771,
#    'time_signature': 4},
#   {'danceability': 0.406,
#    'energy': 0.145,
#    'key': 11,
#    'loudness': -10.571,
#    'mode': 1,
#    'speechiness': 0.0398,
#    'acousticness': 0.97,
#    'instrumentalness': 3.1e-06,
#    'liveness': 0.161,
#    'valence': 0.346,
#    'tempo': 131.974,
#    'type': 'audio_features',
#    'id': '6H6S0juPYrUnOuCygmD0k6',
#    'uri': 'spotify:track:6H6S0juPYrUnOuCygmD0k6',
#    'track_href': 'https://api.spotify.com/v1/tracks/6H6S0juPYrUnOuCygmD0k6',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6H6S0juPYrUnOuCygmD0k6',
#    'duration_ms': 308989,
#    'time_signature': 4},
#   {'danceability': 0.428,
#    'energy': 0.313,
#    'key': 8,
#    'loudness': -7.327,
#    'mode': 1,
#    'speechiness': 0.0391,
#    'acousticness': 0.757,
#    'instrumentalness': 0,
#    'liveness': 0.309,
#    'valence': 0.284,
#    'tempo': 78.723,
#    'type': 'audio_features',
#    'id': '3P3UA61WRQqwCXaoFOTENd',
#    'uri': 'spotify:track:3P3UA61WRQqwCXaoFOTENd',
#    'track_href': 'https://api.spotify.com/v1/tracks/3P3UA61WRQqwCXaoFOTENd',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3P3UA61WRQqwCXaoFOTENd',
#    'duration_ms': 253293,
#    'time_signature': 4},
#   {'danceability': 0.312,
#    'energy': 0.589,
#    'key': 2,
#    'loudness': -5.071,
#    'mode': 1,
#    'speechiness': 0.0334,
#    'acousticness': 0.459,
#    'instrumentalness': 0,
#    'liveness': 0.106,
#    'valence': 0.237,
#    'tempo': 133.854,
#    'type': 'audio_features',
#    'id': '1DP0uwV6tMlCEfR61Mh7ki',
#    'uri': 'spotify:track:1DP0uwV6tMlCEfR61Mh7ki',
#    'track_href': 'https://api.spotify.com/v1/tracks/1DP0uwV6tMlCEfR61Mh7ki',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1DP0uwV6tMlCEfR61Mh7ki',
#    'duration_ms': 289580,
#    'time_signature': 3},
#   {'danceability': 0.344,
#    'energy': 0.281,
#    'key': 1,
#    'loudness': -9.59,
#    'mode': 1,
#    'speechiness': 0.0545,
#    'acousticness': 0.828,
#    'instrumentalness': 0,
#    'liveness': 0.118,
#    'valence': 0.37,
#    'tempo': 74.998,
#    'type': 'audio_features',
#    'id': '0ESGvKJoja4msEeDhOMDD8',
#    'uri': 'spotify:track:0ESGvKJoja4msEeDhOMDD8',
#    'track_href': 'https://api.spotify.com/v1/tracks/0ESGvKJoja4msEeDhOMDD8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ESGvKJoja4msEeDhOMDD8',
#    'duration_ms': 239123,
#    'time_signature': 4},
#   {'danceability': 0.652,
#    'energy': 0.18,
#    'key': 5,
#    'loudness': -9.735,
#    'mode': 0,
#    'speechiness': 0.111,
#    'acousticness': 0.743,
#    'instrumentalness': 4.04e-06,
#    'liveness': 0.71,
#    'valence': 0.328,
#    'tempo': 115.218,
#    'type': 'audio_features',
#    'id': '1zJpJ3HPRtAYYNLWm5BJEf',
#    'uri': 'spotify:track:1zJpJ3HPRtAYYNLWm5BJEf',
#    'track_href': 'https://api.spotify.com/v1/tracks/1zJpJ3HPRtAYYNLWm5BJEf',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1zJpJ3HPRtAYYNLWm5BJEf',
#    'duration_ms': 261120,
#    'time_signature': 3},
#   {'danceability': 0.667,
#    'energy': 0.361,
#    'key': 1,
#    'loudness': -8.69,
#    'mode': 0,
#    'speechiness': 0.0273,
#    'acousticness': 0.575,
#    'instrumentalness': 0.00506,
#    'liveness': 0.0805,
#    'valence': 0.29,
#    'tempo': 134.018,
#    'type': 'audio_features',
#    'id': '2jdAk8ATWIL3dwT47XpRfu',
#    'uri': 'spotify:track:2jdAk8ATWIL3dwT47XpRfu',
#    'track_href': 'https://api.spotify.com/v1/tracks/2jdAk8ATWIL3dwT47XpRfu',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2jdAk8ATWIL3dwT47XpRfu',
#    'duration_ms': 242000,
#    'time_signature': 5},
#   {'danceability': 0.606,
#    'energy': 0.441,
#    'key': 9,
#    'loudness': -9.303,
#    'mode': 1,
#    'speechiness': 0.0272,
#    'acousticness': 0.326,
#    'instrumentalness': 0.0128,
#    'liveness': 0.116,
#    'valence': 0.455,
#    'tempo': 66.443,
#    'type': 'audio_features',
#    'id': '5gbxzSqABThINGDb7vIiwe',
#    'uri': 'spotify:track:5gbxzSqABThINGDb7vIiwe',
#    'track_href': 'https://api.spotify.com/v1/tracks/5gbxzSqABThINGDb7vIiwe',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5gbxzSqABThINGDb7vIiwe',
#    'duration_ms': 332067,
#    'time_signature': 3},
#   {'danceability': 0.753,
#    'energy': 0.326,
#    'key': 7,
#    'loudness': -9.883,
#    'mode': 1,
#    'speechiness': 0.0342,
#    'acousticness': 0.731,
#    'instrumentalness': 0.00131,
#    'liveness': 0.24,
#    'valence': 0.237,
#    'tempo': 123.799,
#    'type': 'audio_features',
#    'id': '3SktMqZmo3M9zbB7oKMIF7',
#    'uri': 'spotify:track:3SktMqZmo3M9zbB7oKMIF7',
#    'track_href': 'https://api.spotify.com/v1/tracks/3SktMqZmo3M9zbB7oKMIF7',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3SktMqZmo3M9zbB7oKMIF7',
#    'duration_ms': 245827,
#    'time_signature': 3},
#   {'danceability': 0.549,
#    'energy': 0.324,
#    'key': 4,
#    'loudness': -11.769,
#    'mode': 1,
#    'speechiness': 0.0285,
#    'acousticness': 0.457,
#    'instrumentalness': 2.2e-06,
#    'liveness': 0.133,
#    'valence': 0.268,
#    'tempo': 80.888,
#    'type': 'audio_features',
#    'id': '3MthJpM1IEYp2ulZe00LvP',
#    'uri': 'spotify:track:3MthJpM1IEYp2ulZe00LvP',
#    'track_href': 'https://api.spotify.com/v1/tracks/3MthJpM1IEYp2ulZe00LvP',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3MthJpM1IEYp2ulZe00LvP',
#    'duration_ms': 236733,
#    'time_signature': 4},
#   {'danceability': 0.635,
#    'energy': 0.562,
#    'key': 9,
#    'loudness': -7.315,
#    'mode': 1,
#    'speechiness': 0.0223,
#    'acousticness': 0.387,
#    'instrumentalness': 0.000366,
#    'liveness': 0.113,
#    'valence': 0.501,
#    'tempo': 97.988,
#    'type': 'audio_features',
#    'id': '3hwjxbqGvTRUPi38fLgeM7',
#    'uri': 'spotify:track:3hwjxbqGvTRUPi38fLgeM7',
#    'track_href': 'https://api.spotify.com/v1/tracks/3hwjxbqGvTRUPi38fLgeM7',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3hwjxbqGvTRUPi38fLgeM7',
#    'duration_ms': 255213,
#    'time_signature': 4},
#   {'danceability': 0.427,
#    'energy': 0.588,
#    'key': 2,
#    'loudness': -6.721,
#    'mode': 1,
#    'speechiness': 0.0293,
#    'acousticness': 0.0538,
#    'instrumentalness': 0.0014,
#    'liveness': 0.0697,
#    'valence': 0.394,
#    'tempo': 145.099,
#    'type': 'audio_features',
#    'id': '7MRn6wgG0ReDRNYV5wJeGX',
#    'uri': 'spotify:track:7MRn6wgG0ReDRNYV5wJeGX',
#    'track_href': 'https://api.spotify.com/v1/tracks/7MRn6wgG0ReDRNYV5wJeGX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7MRn6wgG0ReDRNYV5wJeGX',
#    'duration_ms': 367813,
#    'time_signature': 4},
#   {'danceability': 0.495,
#    'energy': 0.238,
#    'key': 1,
#    'loudness': -11.026,
#    'mode': 1,
#    'speechiness': 0.03,
#    'acousticness': 0.958,
#    'instrumentalness': 0.0118,
#    'liveness': 0.0875,
#    'valence': 0.357,
#    'tempo': 175.958,
#    'type': 'audio_features',
#    'id': '78DwRIo6Vj6wqteyerGetr',
#    'uri': 'spotify:track:78DwRIo6Vj6wqteyerGetr',
#    'track_href': 'https://api.spotify.com/v1/tracks/78DwRIo6Vj6wqteyerGetr',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/78DwRIo6Vj6wqteyerGetr',
#    'duration_ms': 198200,
#    'time_signature': 4},
#   {'danceability': 0.718,
#    'energy': 0.583,
#    'key': 7,
#    'loudness': -7.884,
#    'mode': 1,
#    'speechiness': 0.0288,
#    'acousticness': 0.623,
#    'instrumentalness': 0.000681,
#    'liveness': 0.0612,
#    'valence': 0.422,
#    'tempo': 119.971,
#    'type': 'audio_features',
#    'id': '0oiCeOPwm4zhwfyIpAE37y',
#    'uri': 'spotify:track:0oiCeOPwm4zhwfyIpAE37y',
#    'track_href': 'https://api.spotify.com/v1/tracks/0oiCeOPwm4zhwfyIpAE37y',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0oiCeOPwm4zhwfyIpAE37y',
#    'duration_ms': 212320,
#    'time_signature': 4},
#   {'danceability': 0.85,
#    'energy': 0.461,
#    'key': 6,
#    'loudness': -9.018,
#    'mode': 0,
#    'speechiness': 0.0531,
#    'acousticness': 0.591,
#    'instrumentalness': 0.0405,
#    'liveness': 0.0922,
#    'valence': 0.621,
#    'tempo': 94.037,
#    'type': 'audio_features',
#    'id': '1crSsvtU9wZB15dIQXV2QH',
#    'uri': 'spotify:track:1crSsvtU9wZB15dIQXV2QH',
#    'track_href': 'https://api.spotify.com/v1/tracks/1crSsvtU9wZB15dIQXV2QH',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1crSsvtU9wZB15dIQXV2QH',
#    'duration_ms': 265360,
#    'time_signature': 4},
#   {'danceability': 0.758,
#    'energy': 0.465,
#    'key': 7,
#    'loudness': -6.547,
#    'mode': 1,
#    'speechiness': 0.0374,
#    'acousticness': 0.489,
#    'instrumentalness': 5.13e-05,
#    'liveness': 0.116,
#    'valence': 0.758,
#    'tempo': 138.9,
#    'type': 'audio_features',
#    'id': '5KsLlcmWDoHUoJFzRw14wD',
#    'uri': 'spotify:track:5KsLlcmWDoHUoJFzRw14wD',
#    'track_href': 'https://api.spotify.com/v1/tracks/5KsLlcmWDoHUoJFzRw14wD',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5KsLlcmWDoHUoJFzRw14wD',
#    'duration_ms': 240627,
#    'time_signature': 4},
#   {'danceability': 0.693,
#    'energy': 0.666,
#    'key': 0,
#    'loudness': -9.47,
#    'mode': 1,
#    'speechiness': 0.0492,
#    'acousticness': 0.255,
#    'instrumentalness': 0.301,
#    'liveness': 0.101,
#    'valence': 0.695,
#    'tempo': 95.022,
#    'type': 'audio_features',
#    'id': '5OE6NKJ7dcDbvoNg1z0Cgf',
#    'uri': 'spotify:track:5OE6NKJ7dcDbvoNg1z0Cgf',
#    'track_href': 'https://api.spotify.com/v1/tracks/5OE6NKJ7dcDbvoNg1z0Cgf',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5OE6NKJ7dcDbvoNg1z0Cgf',
#    'duration_ms': 218392,
#    'time_signature': 4},
#   {'danceability': 0.785,
#    'energy': 0.394,
#    'key': 4,
#    'loudness': -8.01,
#    'mode': 1,
#    'speechiness': 0.0392,
#    'acousticness': 0.572,
#    'instrumentalness': 0.000801,
#    'liveness': 0.111,
#    'valence': 0.131,
#    'tempo': 100.002,
#    'type': 'audio_features',
#    'id': '0ORL2BIQwHdshE8Zp2En2M',
#    'uri': 'spotify:track:0ORL2BIQwHdshE8Zp2En2M',
#    'track_href': 'https://api.spotify.com/v1/tracks/0ORL2BIQwHdshE8Zp2En2M',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ORL2BIQwHdshE8Zp2En2M',
#    'duration_ms': 258747,
#    'time_signature': 4},
#   {'danceability': 0.375,
#    'energy': 0.282,
#    'key': 4,
#    'loudness': -11.761,
#    'mode': 1,
#    'speechiness': 0.0409,
#    'acousticness': 0.897,
#    'instrumentalness': 0.00168,
#    'liveness': 0.0952,
#    'valence': 0.295,
#    'tempo': 77.656,
#    'type': 'audio_features',
#    'id': '5y2TuOFgwlpztHlqENHQOE',
#    'uri': 'spotify:track:5y2TuOFgwlpztHlqENHQOE',
#    'track_href': 'https://api.spotify.com/v1/tracks/5y2TuOFgwlpztHlqENHQOE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5y2TuOFgwlpztHlqENHQOE',
#    'duration_ms': 219300,
#    'time_signature': 4},
#   {'danceability': 0.758,
#    'energy': 0.451,
#    'key': 4,
#    'loudness': -7.467,
#    'mode': 0,
#    'speechiness': 0.0414,
#    'acousticness': 0.541,
#    'instrumentalness': 0.00283,
#    'liveness': 0.11,
#    'valence': 0.292,
#    'tempo': 122.098,
#    'type': 'audio_features',
#    'id': '2NfLgvpXpGKAcOAQwMPzez',
#    'uri': 'spotify:track:2NfLgvpXpGKAcOAQwMPzez',
#    'track_href': 'https://api.spotify.com/v1/tracks/2NfLgvpXpGKAcOAQwMPzez',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2NfLgvpXpGKAcOAQwMPzez',
#    'duration_ms': 231639,
#    'time_signature': 4}])

# %%
df = pd.DataFrame(get_song_features())
print(df)
# Out:
#                                                  0    \
# 0                                    Feel Invincible
# 1                                            Skillet
# 2  {'danceability': 0.603, 'energy': 0.886, 'key'...
#
#                                                  1    \
# 0                                            Save Me
# 1                                            Skillet
# 2  {'danceability': 0.556, 'energy': 0.888, 'key'...
#
#                                                  2    \
# 0                                           Dominion
# 1                                            Skillet
# 2  {'danceability': 0.407, 'energy': 0.99, 'key':...
#
#                                                  3    \
# 0                                   Hail to the King
# 1                                  Avenged Sevenfold
# 2  {'danceability': 0.58, 'energy': 0.916, 'key':...
#
#                                                  4    \
# 0                                    One Step Closer
# 1                                        Linkin Park
# 2  {'danceability': 0.492, 'energy': 0.969, 'key'...
#
#                                                  5    \
# 0                                        Open Wounds
# 1                                            Skillet
# 2  {'danceability': 0.573, 'energy': 0.922, 'key'...
#
#                                                  6    \
# 0                                            Respect
# 1                                     Devour the Day
# 2  {'danceability': 0.654, 'energy': 0.818, 'key'...
#
#                                                  7    \
# 0                                              Vapor
# 1                                            Skillet
# 2  {'danceability': 0.394, 'energy': 0.982, 'key'...
#
#                                                  8    \
# 0                                  Since U Been Gone
# 1                                  A Day To Remember
# 2  {'danceability': 0.625, 'energy': 0.951, 'key'...
#
#                                                  9    ...  \
# 0                                             Energy  ...
# 1                                            Skillet  ...
# 2  {'danceability': 0.441, 'energy': 0.958, 'key'...  ...
#
#                                                  290  \
# 0                                 Why You No Love Me
# 1                                         John Mayer
# 2  {'danceability': 0.635, 'energy': 0.562, 'key'...
#
#                                                  291  \
# 0                                          In Repair
# 1                                         John Mayer
# 2  {'danceability': 0.427, 'energy': 0.588, 'key'...
#
#                                                  292  \
# 0                                  The Heart of Life
# 1                                         John Mayer
# 2  {'danceability': 0.495, 'energy': 0.238, 'key'...
#
#                                                  293  \
# 0                                Love on the Weekend
# 1                                         John Mayer
# 2  {'danceability': 0.718, 'energy': 0.583, 'key'...
#
#                                                  294  \
# 0                         Moving On and Getting Over
# 1                                         John Mayer
# 2  {'danceability': 0.85, 'energy': 0.461, 'key':...
#
#                                                  295  \
# 0                                              Rosie
# 1                                         John Mayer
# 2  {'danceability': 0.758, 'energy': 0.465, 'key'...
#
#                                                  296  \
# 0                             Transcend - feat. Armi
# 1                                              Ovall
# 2  {'danceability': 0.693, 'energy': 0.666, 'key'...
#
#                                                  297  \
# 0                                  You're On My Mind
# 1                                          Tom Misch
# 2  {'danceability': 0.785, 'energy': 0.394, 'key'...
#
#                                                  298  \
# 0                                       golden thing
# 1                                       Cody Simpson
# 2  {'danceability': 0.375, 'energy': 0.282, 'key'...
#
#                                                  299
# 0                                            Tonight
# 1                                        Stephen Day
# 2  {'danceability': 0.758, 'energy': 0.451, 'key'...
#
# [3 rows x 300 columns]

# %%
# Song Names
df.iloc[0]
# Out:
# 0             Feel Invincible
# 1                     Save Me
# 2                    Dominion
# 3            Hail to the King
# 4             One Step Closer
#                 ...
# 295                     Rosie
# 296    Transcend - feat. Armi
# 297         You're On My Mind
# 298              golden thing
# 299                   Tonight
# Name: 0, Length: 300, dtype: object

# %%
# Artist Names
df.iloc[1]
# Out:
# 0                Skillet
# 1                Skillet
# 2                Skillet
# 3      Avenged Sevenfold
# 4            Linkin Park
#              ...
# 295           John Mayer
# 296                Ovall
# 297            Tom Misch
# 298         Cody Simpson
# 299          Stephen Day
# Name: 1, Length: 300, dtype: object

# %%
# Song Features
df.iloc[2][0]
# Out:
# {'danceability': 0.603,
#  'energy': 0.886,
#  'key': 5,
#  'loudness': -3.777,
#  'mode': 0,
#  'speechiness': 0.0837,
#  'acousticness': 0.00045,
#  'instrumentalness': 0,
#  'liveness': 0.26,
#  'valence': 0.395,
#  'tempo': 126.025,
#  'type': 'audio_features',
#  'id': '0i8JFpqe9cKwnrcvoNgl1L',
#  'uri': 'spotify:track:0i8JFpqe9cKwnrcvoNgl1L',
#  'track_href': 'https://api.spotify.com/v1/tracks/0i8JFpqe9cKwnrcvoNgl1L',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0i8JFpqe9cKwnrcvoNgl1L',
#  'duration_ms': 229933,
#  'time_signature': 4}

# %%
    song = list(df.iloc[0])
    artist = list(df.iloc[1])
    danceability = []
    energy =  []
    key = []
    loudness = []
    mode = []
    speechiness = []
    acousticness = []
    instrumentalness = []
    liveness = []
    valence = []
    tempo = []
    duration_ms = []
    time_signature = []
    

for i in range(300):
        feature = df.iloc[2][i]
    
        danceability.append(feature['danceability'])
        energy.append(feature['energy'])
        key.append(feature['key'])
        loudness.append(feature['loudness'])
        mode.append(feature['mode'])
        speechiness.append(feature['speechiness'])
        acousticness.append(feature['acousticness'])
        instrumentalness.append(feature['instrumentalness'])
        liveness.append(feature['liveness'])
        valence.append(feature['valence'])
        tempo.append(feature['tempo'])
        duration_ms.append(feature['duration_ms'])
        time_signature.append(feature['time_signature'])

# %%
data = [ song,artist, danceability,
    energy,
    key,
    loudness,
    mode,
    speechiness,
    acousticness,
    instrumentalness,
    liveness,
    valence,
    tempo,
    duration_ms,
    time_signature
       ]

# %%
df2 = pd.DataFrame(data = data)
print(df2)
# Out:
#                 0         1         2                  3                4    \
# 0   Feel Invincible   Save Me  Dominion   Hail to the King  One Step Closer
# 1           Skillet   Skillet   Skillet  Avenged Sevenfold      Linkin Park
# 2             0.603     0.556     0.407               0.58            0.492
# 3             0.886     0.888      0.99              0.916            0.969
# 4                 5         1        11                  3                9
# 5            -3.777    -3.985    -3.969             -4.358           -4.419
# 6                 0         0         0                  0                1
# 7            0.0837    0.0377     0.171             0.0387           0.0491
# 8           0.00045  0.000377    0.0306           0.000297           0.0014
# 9                 0         0         0             0.0259         0.000001
# 10             0.26     0.214    0.0708              0.126           0.0787
# 11            0.395     0.446     0.186              0.683            0.538
# 12          126.025    96.033   164.977            118.004           95.136
# 13           229933    223241    231492             305907           157333
# 14                4         4         4                  4                4
#
#             5               6         7                  8         9    ...  \
# 0   Open Wounds         Respect     Vapor  Since U Been Gone    Energy  ...
# 1       Skillet  Devour the Day   Skillet  A Day To Remember   Skillet  ...
# 2         0.573           0.654     0.394              0.625     0.441  ...
# 3         0.922           0.818     0.982              0.951     0.958  ...
# 4             0               8         5                  3         7  ...
# 5        -4.013           -6.12     -3.94             -5.209    -3.256  ...
# 6             1               1         1                  1         1  ...
# 7        0.0695          0.0434    0.0839             0.0494    0.0757  ...
# 8        0.0595         0.00012  0.000095            0.00497  0.000413  ...
# 9             0        0.000074  0.000003                  0  0.000023  ...
# 10        0.414           0.233    0.0665              0.106     0.103  ...
# 11        0.503           0.348     0.412              0.721     0.354  ...
# 12      101.099         118.045    188.29             128.01    92.974  ...
# 13       194773          171262    218707             198267    236693  ...
# 14            4               4         4                  4         4  ...
#
#                    290         291                292                  293  \
# 0   Why You No Love Me   In Repair  The Heart of Life  Love on the Weekend
# 1           John Mayer  John Mayer         John Mayer           John Mayer
# 2                0.635       0.427              0.495                0.718
# 3                0.562       0.588              0.238                0.583
# 4                    9           2                  1                    7
# 5               -7.315      -6.721            -11.026               -7.884
# 6                    1           1                  1                    1
# 7               0.0223      0.0293               0.03               0.0288
# 8                0.387      0.0538              0.958                0.623
# 9             0.000366      0.0014             0.0118             0.000681
# 10               0.113      0.0697             0.0875               0.0612
# 11               0.501       0.394              0.357                0.422
# 12              97.988     145.099            175.958              119.971
# 13              255213      367813             198200               212320
# 14                   4           4                  4                    4
#
#                            294         295                     296  \
# 0   Moving On and Getting Over       Rosie  Transcend - feat. Armi
# 1                   John Mayer  John Mayer                   Ovall
# 2                         0.85       0.758                   0.693
# 3                        0.461       0.465                   0.666
# 4                            6           7                       0
# 5                       -9.018      -6.547                   -9.47
# 6                            0           1                       1
# 7                       0.0531      0.0374                  0.0492
# 8                        0.591       0.489                   0.255
# 9                       0.0405    0.000051                   0.301
# 10                      0.0922       0.116                   0.101
# 11                       0.621       0.758                   0.695
# 12                      94.037       138.9                  95.022
# 13                      265360      240627                  218392
# 14                           4           4                       4
#
#                   297           298          299
# 0   You're On My Mind  golden thing      Tonight
# 1           Tom Misch  Cody Simpson  Stephen Day
# 2               0.785         0.375        0.758
# 3               0.394         0.282        0.451
# 4                   4             4            4
# 5               -8.01       -11.761       -7.467
# 6                   1             1            0
# 7              0.0392        0.0409       0.0414
# 8               0.572         0.897        0.541
# 9            0.000801       0.00168      0.00283
# 10              0.111        0.0952         0.11
# 11              0.131         0.295        0.292
# 12            100.002        77.656      122.098
# 13             258747        219300       231639
# 14                  4             4            4
#
# [15 rows x 300 columns]

# %%
df3 = df2.transpose().rename(columns={0:'song_name', 1:'artist', 2: 'danceability', 3:'energy', 4:'key', 5:'loudness', 6:'mode', 
                     7:'speechiness', 8:'acousticness', 9:'instrumentalness', 10:'liveness', 
                     11:'valence', 12:'tempo', 13:'duration_ms',14:'time_signature'})

# %%
print(df3)
# Out:
#                   song_name             artist danceability energy key  \
# 0           Feel Invincible            Skillet        0.603  0.886   5
# 1                   Save Me            Skillet        0.556  0.888   1
# 2                  Dominion            Skillet        0.407   0.99  11
# 3          Hail to the King  Avenged Sevenfold         0.58  0.916   3
# 4           One Step Closer        Linkin Park        0.492  0.969   9
# ..                      ...                ...          ...    ...  ..
# 295                   Rosie         John Mayer        0.758  0.465   7
# 296  Transcend - feat. Armi              Ovall        0.693  0.666   0
# 297       You're On My Mind          Tom Misch        0.785  0.394   4
# 298            golden thing       Cody Simpson        0.375  0.282   4
# 299                 Tonight        Stephen Day        0.758  0.451   4
#
#     loudness mode speechiness acousticness instrumentalness liveness valence  \
# 0     -3.777    0      0.0837      0.00045                0     0.26   0.395
# 1     -3.985    0      0.0377     0.000377                0    0.214   0.446
# 2     -3.969    0       0.171       0.0306                0   0.0708   0.186
# 3     -4.358    0      0.0387     0.000297           0.0259    0.126   0.683
# 4     -4.419    1      0.0491       0.0014         0.000001   0.0787   0.538
# ..       ...  ...         ...          ...              ...      ...     ...
# 295   -6.547    1      0.0374        0.489         0.000051    0.116   0.758
# 296    -9.47    1      0.0492        0.255            0.301    0.101   0.695
# 297    -8.01    1      0.0392        0.572         0.000801    0.111   0.131
# 298  -11.761    1      0.0409        0.897          0.00168   0.0952   0.295
# 299   -7.467    0      0.0414        0.541          0.00283     0.11   0.292
#
#        tempo duration_ms time_signature
# 0    126.025      229933              4
# 1     96.033      223241              4
# 2    164.977      231492              4
# 3    118.004      305907              4
# 4     95.136      157333              4
# ..       ...         ...            ...
# 295    138.9      240627              4
# 296   95.022      218392              4
# 297  100.002      258747              4
# 298   77.656      219300              4
# 299  122.098      231639              4
#
# [300 rows x 15 columns]

# %%
df3.to_csv('songs_to_ml.csv')
